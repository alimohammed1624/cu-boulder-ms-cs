# %% [markdown]
# # Problem 1
#
# We saw how to solve TSPs in this module and in particular presented two approaches to encode a TSP as an integer linear program. In this problem, we will ask you to adapt the TSP solution to the related problem of $k$ Travelling Salespeople Problem ($k$-TSP).
#
# Let $G$ be a complete graph with $n$ vertices that we will label $0, \ldots, n-1$ (keeping Python array indexing in mind). Our costs are specified using a matrix $C$ wherein $C_{i,j}$ is the cost of the edge from vertex $i$ to $j$ for $i \not= j$.
#
# In this problem, we have $k \geq 1$ salespeople who must  start from vertex $0$ of the graph (presumably the location of the sales office) and together visit every location in the graph,  each returning back to vertex $0$. Each location must be visited exactly once by some salesperson in the team. Therefore, other than vertex $0$ (the start/end vertex of every salesperson's tour), no two salesperson tours have a vertex in common. Notice that for $k=1$, this is just the regular TSP problem we have studied.
#
# Also, all $k$ salespeople must be employed in the tour. In other words, if we have $k=3$ then each salesperson must start at $0$ and visit a sequence of one or more vertices and come back to $0$. No salesperson can be "idle".
#
# ## Example-1
#
# Consider a graph with $5$ nodes and the following cost matrix:
#
# $$ \begin{array}{c|ccccc}
#   \text{Vertices} & 0 & 1 & 2 & 3 & 4 \\
#    \hline
#  0 & - & 3 & 4 & 3 & 5 \\
#  1 & 1 & - & 2 & 4 & 1 \\
#  2 & 2 & 1 & - & 5 & 4 \\
#  3 & 1 & 1 & 5 & - & 4 \\
#  4 & 2 & 1 & 3 & 5 & - \\
#  \end{array}$$
#
#  For instance $C_{2,3}$ the cost of edge from vertex $2$ to $3$ is $5$. The $-$ in the diagonal entries simply tells us that we do not care what goes in there since we do not have self-loops in the graph.
#
# The optimal $2$-TSP tour for $k=2$ salespeople is shown below.
#   - Salesperson # 1: $0 \rightarrow 2 \rightarrow 1 \rightarrow 4 \rightarrow 0$.
#   - Salesperson # 2: $0 \rightarrow 3 \rightarrow 0$.
#
# The total cost of the edges traversed by the two salespeople equals $12$.
#
# For $k=3$, the optimal $3-$ TSP tour is as shown below.
#   - Salesperson # 1: $0 \rightarrow 1 \rightarrow 4$,
#   - Salesperson # 2: $0 \rightarrow 2$,
#   - Salesperson # 3: $0 \rightarrow 3$.
#
# The total cost is $16$.
#
# The objective of this problem is to formulate an ILP using the MTZ approach.

# %% [markdown]
# ### Problem 1A (MTZ approach)
#
# We will use the same ILP setup as in our notes (see the notes on Exact Approaches to TSP that includes the ILP encodings we will use in this problem).
#   - Decision variables $x_{i,j}$ for $i \not= j$ denoting that the tour traverses the edge from $i$ to $j$.
#   - Time stamps $t_1, \ldots, t_{n-1}$. The start/end vertex $0$ does not get a time stamp.
#
# Modify the MTZ approach to incorporate the fact that $k$ salespeople are going to traverse the graph.
#
# #### (A) Degree Constraints
#
# What do the new degree constraints look like? Think about how many edges in the tour will need to enter/leave each vertex? Note that you may have to treat vertex $0$ differently from the other vertices of the graph.
#
# Your answer below is not graded. However you are encouraged to write it down and check with the answers to select problems provided at the end.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### (B) Time Stamp Constraints
#
# Formulate the time stamp constraints for the $k$-TSP problem. Think about how you would need to change them to eliminate subtour.
#
# Your answer below is not graded. However you are encouraged to write it down and check with the answers to select problems provided at the end.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### (C) Implement
#
# Complete the implementation of the function `k_tsp_mtz_encoding(n, k, cost_matrix)` below. It follows the same input convention as the code supplied in the notes. The input `n` denotes the size of the graph with vertices labeled `0`,.., `n-1`, `k` is the number of salespeople, and `cost_matrix` is a list of lists wherein `cost_matrix[i][j]` is the edge cost to go from `i` to `j` for `i != j`. Your code must avoid accessing `cost_matrix[i][i]` to avoid bugs. These entries will be supplied as `None` in the test cases.
#
# Your code must return a list `lst` that has exactly $k$ lists in it, wherein `lst[j]` represents the locations visited by the $j^{th}$ salesperson.
#
# For the example above, for $k=2$, your code must return
# ~~~
# [ [0, 2, 1, 4], [0, 3] ]
# ~~~
# For the example above, for $k=3$, your code must return
# ~~~
# [ [0, 1, 4], [0, 2], [0, 3] ]
# ~~~

# %%
from pulp import *
def k_tsp_mtz_encoding(n, k, cost_matrix):
    # check inputs are OK
    assert 1 <= k < n
    assert len(cost_matrix) == n, f'Cost matrix is not {n}x{n}'
    assert all(len(cj) == n for cj in cost_matrix), f'Cost matrix is not {n}x{n}'
    prob = LpProblem('kTSP', LpMinimize)
    # finish your implementation here
    # your code must return a list of k-lists [ [0, i1, ..., il], [0, j1,...,jl],...] wherein 
    # the ith entry in our list of lists represents the 
    # tour undertaken by the ith salesperson
    # your code here
    dVars = [[[LpVariable(f'x{i}_{j}', lowBound=0, upBound=1, cat="Integer") for j in range(n)] for i in  range(n)],[LpVariable(f't{i}', lowBound=0, cat="Integer") for i in range(n)]]

    # Objective function
    prob += lpSum([cost_matrix[i][j] * dVars[0][i][j] if i!=j else None for i in range(n) for j in range(n)])

    # Constraints
    prob += lpSum([dVars[0][0][j] for j in range(1, n)]) == k
    prob += lpSum([dVars[0][j][0] for j in range(1, n)]) == k
    for i in range(1,n):
        prob += lpSum([dVars[0][i][j] for j in range(n)]) == 1
        prob += lpSum([dVars[0][j][i] for j in range(n)]) == 1

    for i in range(n):
        for j in range(n):
            if i!=j and i!=0 and j!=0:
                prob += dVars[1][i] - dVars[1][j] + dVars[0][i][j] - (n - 1) * (1 - dVars[0][i][j]) <= 0
            elif i == j:
                prob += dVars[0][i][j] == 0

    prob.solve()

    tours = []
    vertices = [i for i in range(1,n)] + [0]*k
    for i in range(k):
        j = 0
        tour = [0]
        while len(vertices) > 0:
            for l in vertices:
                if dVars[0][j][l].varValue == 1:
                    if l!=0: tour.append(l)
                    vertices.remove(l)
                    j = l
                    break
            if j == 0:
                tours.append(tour)
                break
    return tours

    raise NotImplementedError

# %%
cost_matrix=[ [None,3,4,3,5],
             [1, None, 2,4, 1],
             [2, 1, None, 5, 4],
             [1, 1, 5, None, 4],
             [2, 1, 3, 5, None] ]
n=5
k=2
all_tours = k_tsp_mtz_encoding(n, k, cost_matrix)
print(f'Your code returned tours: {all_tours}')
assert len(all_tours) == k, f'k={k} must yield two tours -- your code returns {len(all_tours)} tours instead'

tour_cost = 0
for tour in all_tours:
    assert tour[0] == 0, 'Each salesperson tour must start from vertex 0'
    i = 0
    for j in tour[1:]:
        tour_cost += cost_matrix[i][j]
        i = j
    tour_cost += cost_matrix[i][0]

print(f'Tour cost obtained by your code: {tour_cost}')
assert abs(tour_cost - 12) <= 0.001, f'Expected tour cost is 12, your code returned {tour_cost}'
for i in range(1, n):
    is_in_tour = [ 1 if i in tour else 0 for tour in all_tours]
    assert sum(is_in_tour) == 1, f' vertex {i} is in {sum(is_in_tour)} tours -- this is incorrect'

print('test passed: 3 points')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/e85d0a2fe9794297be6c5fa398f1f0fc-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/e85d0a2fe9794297be6c5fa398f1f0fc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 200 RHS
# At line 228 BOUNDS
# At line 258 ENDATA
# Problem MODEL has 27 rows, 29 columns and 89 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 12 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 22 rows, 24 columns (24 integer (20 of which binary)) and 76 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.6
# Cbc0038I Pass   1: suminf.    1.60000 (8) obj. 12.4 iterations 5
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 14 iterations 7
# Cbc0038I Solution found of 14
# Cbc0038I Cleaned solution of 14
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 24 columns, reduced to 5 rows 6 columns
# Cbc0038I Mini branch and bound improved solution from 14 to 12 (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 12 - took 0.00 seconds
# Cbc0012I Integer solution of 12 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective 12, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 12 to 12
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                12.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Your code returned tours: [[0, 2, 1, 4], [0, 3]]
# Tour cost obtained by your code: 12
# test passed: 3 points

# %%
cost_matrix=[ [None,3,4,3,5],
             [1, None, 2,4, 1],
             [2, 1, None, 5, 4],
             [1, 1, 5, None, 4],
             [2, 1, 3, 5, None] ]
n=5
k=3
all_tours = k_tsp_mtz_encoding(n, k, cost_matrix)
print(f'Your code returned tours: {all_tours}')
assert len(all_tours) == k, f'k={k} must yield two tours -- your code returns {len(all_tours)} tours instead'

tour_cost = 0
for tour in all_tours:
    assert tour[0] == 0, 'Each salesperson tour must start from vertex 0'
    i = 0
    for j in tour[1:]:
        tour_cost += cost_matrix[i][j]
        i = j
    tour_cost += cost_matrix[i][0]

print(f'Tour cost obtained by your code: {tour_cost}')
assert abs(tour_cost - 16) <= 0.001, f'Expected tour cost is 16, your code returned {tour_cost}'
for i in range(1, n):
    is_in_tour = [ 1 if i in tour else 0 for tour in all_tours]
    assert sum(is_in_tour) == 1, f' vertex {i} is in {sum(is_in_tour)} tours -- this is incorrect'

print('test passed: 2 points')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/82167f035dd2454997c5cbaa25cfb2c1-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/82167f035dd2454997c5cbaa25cfb2c1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 200 RHS
# At line 228 BOUNDS
# At line 258 ENDATA
# Problem MODEL has 27 rows, 29 columns and 89 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 16 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 13 rows, 16 columns (16 integer (12 of which binary)) and 48 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 2.22045e-16
# Cbc0038I Solution found of 16
# Cbc0038I Cleaned solution of 16
# Cbc0038I Before mini branch and bound, 16 integers at bound fixed and 0 continuous of which 1 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 16 - took 0.00 seconds
# Cbc0012I Integer solution of 16 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 16, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 16 to 16
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                16.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Your code returned tours: [[0, 1, 4], [0, 2], [0, 3]]
# Tour cost obtained by your code: 16
# test passed: 2 points

# %%
cost_matrix = [ 
 [None, 1, 1, 1, 1, 1, 1, 1],
    [0, None, 1, 2, 1, 1, 1, 1],
    [1, 0, None, 1, 2, 2, 2, 1],
    [1, 2, 2, None, 0, 1, 2, 1],
    [1, 1, 1, 1, None, 1, 1, 1],
    [0,  1, 2, 1, 1, None, 1, 1],
    [1, 0,  1, 2, 2, 2,None, 1],
    [1, 2, 2, 0, 1, 2, 1, None],
]
n = 8
k = 2

all_tours = k_tsp_mtz_encoding(n, k, cost_matrix)
print(f'Your code returned tours: {all_tours}')
assert len(all_tours) == k, f'k={k} must yield two tours -- your code returns {len(all_tours)} tours instead'

tour_cost = 0
for tour in all_tours:
    assert tour[0] == 0, 'Each salesperson tour must start from vertex 0'
    i = 0
    for j in tour[1:]:
        tour_cost += cost_matrix[i][j]
        i = j
    tour_cost += cost_matrix[i][0]

print(f'Tour cost obtained by your code: {tour_cost}')
assert abs(tour_cost - 4) <= 0.001, f'Expected tour cost is 4, your code returned {tour_cost}'
for i in range(1, n):
    is_in_tour = [ 1 if i in tour else 0 for tour in all_tours]
    assert sum(is_in_tour) == 1, f' vertex {i} is in {sum(is_in_tour)} tours -- this is incorrect'

print('test passed: 3 points')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/34ff4b0fe0a5445f862df3ecda9d6895-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/34ff4b0fe0a5445f862df3ecda9d6895-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 71 COLUMNS
# At line 524 RHS
# At line 591 BOUNDS
# At line 663 ENDATA
# Problem MODEL has 66 rows, 71 columns and 260 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4 - 0.00 seconds
# Cgl0002I 8 variables fixed
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 58 rows, 63 columns (63 integer (56 of which binary)) and 238 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 9 integers unsatisfied sum - 2.25
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 4 iterations 8
# Cbc0038I Solution found of 4
# Cbc0038I Cleaned solution of 4
# Cbc0038I Before mini branch and bound, 51 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 4 - took 0.00 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4 to 4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Your code returned tours: [[0, 6, 2, 1], [0, 7, 3, 4, 5]]
# Tour cost obtained by your code: 4
# test passed: 3 points

# %%
cost_matrix = [ 
 [None, 1, 1, 1, 1, 1, 1, 1],
    [0, None, 1, 2, 1, 1, 1, 1],
    [1, 0, None, 1, 2, 2, 2, 1],
    [1, 2, 2, None, 0, 1, 2, 1],
    [1, 1, 1, 1, None, 1, 1, 1],
    [0,  1, 2, 1, 1, None, 1, 1],
    [1, 0,  1, 2, 2, 2,None, 1],
    [1, 2, 2, 0, 1, 2, 1, None],
]
n = 8
k = 4

all_tours = k_tsp_mtz_encoding(n, k, cost_matrix)
print(f'Your code returned tours: {all_tours}')
assert len(all_tours) == k, f'k={k} must yield two tours -- your code returns {len(all_tours)} tours instead'

tour_cost = 0
for tour in all_tours:
    assert tour[0] == 0, 'Each salesperson tour must start from vertex 0'
    i = 0
    for j in tour[1:]:
        tour_cost += cost_matrix[i][j]
        i = j
    tour_cost += cost_matrix[i][0]

print(f'Tour cost obtained by your code: {tour_cost}')
assert abs(tour_cost - 6) <= 0.001, f'Expected tour cost is 6, your code returned {tour_cost}'
for i in range(1, n):
    is_in_tour = [ 1 if i in tour else 0 for tour in all_tours]
    assert sum(is_in_tour) == 1, f' vertex {i} is in {sum(is_in_tour)} tours -- this is incorrect'

print('test passed: 2 points')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/45ac2f2789834a6cbbd8119ba05376b1-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/45ac2f2789834a6cbbd8119ba05376b1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 71 COLUMNS
# At line 524 RHS
# At line 591 BOUNDS
# At line 663 ENDATA
# Problem MODEL has 66 rows, 71 columns and 260 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6 - 0.00 seconds
# Cgl0002I 8 variables fixed
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 58 rows, 63 columns (63 integer (56 of which binary)) and 238 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 4 integers unsatisfied sum - 0.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 6 iterations 3
# Cbc0038I Solution found of 6
# Cbc0038I Cleaned solution of 6
# Cbc0038I Before mini branch and bound, 58 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 6 - took 0.00 seconds
# Cbc0012I Integer solution of 6 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 6, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6 to 6
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Your code returned tours: [[0, 2], [0, 5], [0, 6, 1], [0, 7, 3, 4]]
# Tour cost obtained by your code: 6
# test passed: 2 points

# %%
from random import uniform, randint

def create_cost(n):
    return [ [uniform(0, 5) if i != j else None for j in range(n)] for i in range(n)]

for trial in range(5):
    print(f'Trial # {trial}')
    n = randint(5, 11)
    k = randint(2, n//2)
    print(f' n= {n}, k={k}')
    cost_matrix = create_cost(n)
    print('cost_matrix = ')
    print(cost_matrix)
    all_tours = k_tsp_mtz_encoding(n, k, cost_matrix)
    print(f'Your code returned tours: {all_tours}')
    assert len(all_tours) == k, f'k={k} must yield two tours -- your code returns {len(all_tours)} tours instead'

    tour_cost = 0
    for tour in all_tours:
        assert tour[0] == 0, 'Each salesperson tour must start from vertex 0'
        i = 0
        for j in tour[1:]:
            tour_cost += cost_matrix[i][j]
            i = j
        tour_cost += cost_matrix[i][0]

    print(f'Tour cost obtained by your code: {tour_cost}')
    #assert abs(tour_cost - 6) <= 0.001, f'Expected tour cost is 6, your code returned {tour_cost}'
    for i in range(1, n):
        is_in_tour = [ 1 if i in tour else 0 for tour in all_tours]
        assert sum(is_in_tour) == 1, f' vertex {i} is in {sum(is_in_tour)} tours -- this is incorrect'
    print('------')
print('test passed: 15 points')
# Out:
# Trial # 0
#  n= 7, k=2
# cost_matrix =
# [[None, 2.0515406361316013, 3.62992685338202, 1.5940816148020338, 1.126428868004155, 3.9393551977148054, 4.731620349715716], [0.39808745284066194, None, 4.390183249015606, 2.184112967838536, 1.9515070022145036, 2.4677142806420442, 0.6977549529588534], [3.914548174086903, 2.582426276100081, None, 4.359077138230106, 1.3594252024650089, 0.03991432629875169, 2.7162791840387204], [4.102204619219774, 4.883541830272021, 4.5908141886560685, None, 3.506180966815455, 0.9754394292289725, 1.3313848964631152], [0.7521990642180543, 1.240184300746171, 2.8103301940369, 1.906005152984331, None, 4.877140111143436, 3.276210913144759], [2.7983788969734427, 2.8695228396416272, 1.6247863924373163, 1.30774369489707, 0.7723095812504382, None, 2.5062099179912307], [0.9933970420843358, 4.063550340092833, 3.345128388510288, 1.4363327341474403, 2.043659215626266, 3.747745249231787, None]]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/fc9381e769fe4effbd970fe52a2a8aed-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/fc9381e769fe4effbd970fe52a2a8aed-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 56 COLUMNS
# At line 402 RHS
# At line 454 BOUNDS
# At line 510 ENDATA
# Problem MODEL has 51 rows, 55 columns and 193 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 8.81763 - 0.00 seconds
# Cgl0002I 7 variables fixed
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 44 rows, 48 columns (48 integer (42 of which binary)) and 174 elements
# Cbc0038I Initial state - 6 integers unsatisfied sum - 1.71429
# Cbc0038I Pass   1: suminf.    1.14286 (4) obj. 9.01124 iterations 13
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 10.6687 iterations 7
# Cbc0038I Solution found of 10.6687
# Cbc0038I Cleaned solution of 10.6687
# Cbc0038I Before mini branch and bound, 34 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 4 rows 3 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 10.4836
# Cbc0038I Reduced cost fixing fixed 15 variables on major pass 2
# Cbc0038I Pass   3: suminf.    1.14286 (4) obj. 9.01124 iterations 0
# Cbc0038I Pass   4: suminf.    1.31910 (7) obj. 10.4836 iterations 8
# Cbc0038I Pass   5: suminf.    1.31910 (7) obj. 10.4836 iterations 1
# Cbc0038I Pass   6: suminf.    1.31910 (7) obj. 10.4836 iterations 1
# Cbc0038I Pass   7: suminf.    1.31910 (7) obj. 10.4836 iterations 1
# Cbc0038I Pass   8: suminf.    1.31910 (7) obj. 10.4836 iterations 3
# Cbc0038I Pass   9: suminf.    1.31910 (7) obj. 10.4836 iterations 3
# Cbc0038I Pass  10: suminf.    1.31910 (7) obj. 10.4836 iterations 6
# Cbc0038I Pass  11: suminf.    2.54700 (6) obj. 10.4836 iterations 12
# Cbc0038I Pass  12: suminf.    2.54700 (6) obj. 10.4836 iterations 3
# Cbc0038I Pass  13: suminf.    2.54700 (6) obj. 10.4836 iterations 4
# Cbc0038I Pass  14: suminf.    2.54700 (6) obj. 10.4836 iterations 3
# Cbc0038I Pass  15: suminf.    1.14286 (4) obj. 9.01124 iterations 10
# Cbc0038I Pass  16: suminf.    2.06993 (7) obj. 10.4836 iterations 8
# Cbc0038I Pass  17: suminf.    2.06993 (7) obj. 10.4836 iterations 0
# Cbc0038I Pass  18: suminf.    2.00000 (6) obj. 10.4836 iterations 9
# Cbc0038I Pass  19: suminf.    1.71429 (4) obj. 10.3137 iterations 2
# Cbc0038I Solution found of 10.2846
# Cbc0038I Cleaned solution of 10.2846
# Cbc0038I Before mini branch and bound, 25 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 14 rows 11 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 9.99123
# Cbc0038I Reduced cost fixing fixed 18 variables on major pass 3
# Cbc0038I Pass  20: suminf.    1.14286 (4) obj. 9.01124 iterations 0
# Cbc0038I Pass  21: suminf.    1.16781 (4) obj. 9.99123 iterations 6
# Cbc0038I Pass  22: suminf.    1.16781 (4) obj. 9.99123 iterations 1
# Cbc0038I Pass  23: suminf.    1.16781 (4) obj. 9.99123 iterations 2
# Cbc0038I Pass  24: suminf.    1.16781 (4) obj. 9.99123 iterations 0
# Cbc0038I Pass  25: suminf.    1.14286 (4) obj. 9.01124 iterations 3
# Cbc0038I Pass  26: suminf.    1.29878 (6) obj. 9.99123 iterations 5
# Cbc0038I Pass  27: suminf.    1.29878 (6) obj. 9.99123 iterations 3
# Cbc0038I Pass  28: suminf.    1.29878 (6) obj. 9.99123 iterations 5
# Cbc0038I Pass  29: suminf.    1.14286 (4) obj. 9.01124 iterations 4
# Cbc0038I Pass  30: suminf.    1.16781 (4) obj. 9.99123 iterations 5
# Cbc0038I Pass  31: suminf.    1.42857 (10) obj. 9.0528 iterations 10
# Cbc0038I Pass  32: suminf.    2.28571 (8) obj. 9.77981 iterations 7
# Cbc0038I Pass  33: suminf.    1.47779 (10) obj. 9.99123 iterations 10
# Cbc0038I Pass  34: suminf.    3.01541 (7) obj. 9.99123 iterations 15
# Cbc0038I Pass  35: suminf.    1.14286 (4) obj. 9.42365 iterations 3
# Cbc0038I Pass  36: suminf.    1.71966 (11) obj. 9.99123 iterations 18
# Cbc0038I Pass  37: suminf.    1.85061 (8) obj. 9.99123 iterations 7
# Cbc0038I Pass  38: suminf.    1.85061 (8) obj. 9.99123 iterations 4
# Cbc0038I Pass  39: suminf.    1.85061 (8) obj. 9.99123 iterations 0
# Cbc0038I Pass  40: suminf.    1.85061 (8) obj. 9.99123 iterations 0
# Cbc0038I Pass  41: suminf.    1.39424 (11) obj. 9.99123 iterations 1
# Cbc0038I Pass  42: suminf.    2.73856 (6) obj. 9.99123 iterations 4
# Cbc0038I Pass  43: suminf.    1.14286 (4) obj. 9.21546 iterations 6
# Cbc0038I Pass  44: suminf.    1.71429 (12) obj. 9.01024 iterations 11
# Cbc0038I Pass  45: suminf.    1.14286 (4) obj. 9.01124 iterations 10
# Cbc0038I Pass  46: suminf.    1.29878 (6) obj. 9.99123 iterations 5
# Cbc0038I Pass  47: suminf.    1.29878 (6) obj. 9.99123 iterations 2
# Cbc0038I Pass  48: suminf.    1.29878 (6) obj. 9.99123 iterations 2
# Cbc0038I Pass  49: suminf.    1.29878 (6) obj. 9.99123 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 21 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 36 rows 20 columns
# Cbc0038I Mini branch and bound improved solution from 10.2846 to 10.0588 (0.02 seconds)
# Cbc0038I Round again with cutoff of 9.63915
# Cbc0038I Reduced cost fixing fixed 21 variables on major pass 4
# Cbc0038I Pass  49: suminf.    1.14286 (4) obj. 9.01124 iterations 0
# Cbc0038I Pass  50: suminf.    1.77473 (4) obj. 9.63915 iterations 6
# Cbc0038I Pass  51: suminf.    1.77473 (4) obj. 9.63915 iterations 3
# Cbc0038I Pass  52: suminf.    1.77473 (4) obj. 9.63915 iterations 2
# Cbc0038I Pass  53: suminf.    1.77473 (4) obj. 9.63915 iterations 1
# Cbc0038I Pass  54: suminf.    1.77473 (4) obj. 9.63915 iterations 0
# Cbc0038I Pass  55: suminf.    1.14286 (4) obj. 9.01124 iterations 3
# Cbc0038I Pass  56: suminf.    1.77473 (4) obj. 9.63915 iterations 7
# Cbc0038I Pass  57: suminf.    1.77473 (4) obj. 9.63915 iterations 2
# Cbc0038I Pass  58: suminf.    1.45318 (7) obj. 9.63915 iterations 5
# Cbc0038I Pass  59: suminf.    1.45318 (7) obj. 9.63915 iterations 1
# Cbc0038I Pass  60: suminf.    1.45318 (7) obj. 9.63915 iterations 0
# Cbc0038I Pass  61: suminf.    1.45318 (7) obj. 9.63915 iterations 0
# Cbc0038I Pass  62: suminf.    1.14286 (4) obj. 9.01124 iterations 8
# Cbc0038I Pass  63: suminf.    1.51040 (6) obj. 9.63915 iterations 7
# Cbc0038I Pass  64: suminf.    1.51040 (6) obj. 9.63915 iterations 1
# Cbc0038I Pass  65: suminf.    1.51040 (6) obj. 9.63915 iterations 0
# Cbc0038I Pass  66: suminf.    1.51040 (6) obj. 9.63915 iterations 1
# Cbc0038I Pass  67: suminf.    1.51040 (6) obj. 9.63915 iterations 1
# Cbc0038I Pass  68: suminf.    1.51040 (6) obj. 9.63915 iterations 0
# Cbc0038I Pass  69: suminf.    2.09207 (6) obj. 9.63915 iterations 10
# Cbc0038I Pass  70: suminf.    2.09207 (6) obj. 9.63915 iterations 3
# Cbc0038I Pass  71: suminf.    2.09207 (6) obj. 9.63915 iterations 2
# Cbc0038I Pass  72: suminf.    2.09207 (6) obj. 9.63915 iterations 1
# Cbc0038I Pass  73: suminf.    1.14286 (4) obj. 9.01124 iterations 5
# Cbc0038I Pass  74: suminf.    1.71429 (6) obj. 8.81763 iterations 7
# Cbc0038I Pass  75: suminf.    1.14286 (4) obj. 9.01124 iterations 8
# Cbc0038I Pass  76: suminf.    1.71429 (6) obj. 9.13158 iterations 14
# Cbc0038I Pass  77: suminf.    1.14286 (4) obj. 9.42365 iterations 7
# Cbc0038I Pass  78: suminf.    1.51435 (4) obj. 9.63915 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 26 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 35 rows 15 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 10.0588 - took 0.01 seconds
# Cbc0012I Integer solution of 10.058827 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0012I Integer solution of 9.9992861 found by DiveCoefficient after 12 iterations and 0 nodes (0.02 seconds)
# Cbc0031I 3 added rows had average density of 4.3333333
# Cbc0013I At root node, 3 cuts changed objective from 8.8176309 to 9.9992861 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3 column cuts (3 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 4.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 15 row cuts average 4.9 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 9.999286067867152, took 12 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 25 variables fixed on reduced cost
# Cuts at root node changed objective from 8.81763 to 9.99929
# Probing was tried 4 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 4 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 4 times and created 15 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                9.99928607
# Enumerated nodes:               0
# Total iterations:               12
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Your code returned tours: [[0, 2, 5, 4, 1], [0, 3, 6]]
# Tour cost obtained by your code: 9.999286067867528
# ------
# Trial # 1
#  n= 11, k=5
# cost_matrix =
# [[None, 3.2094784488839028, 1.9284607629946233, 3.032902924081737, 3.7301690302681028, 3.281147652237102, 0.891725077687967, 3.8462379971756304, 3.515150144517283, 2.4000616701832325, 2.3007310518685644], [1.7426705734990222, None, 4.343491934609514, 4.362784943246406, 4.986068916057447, 1.978077607362494, 2.0993776022198256, 1.0338171000653196, 1.4175179294568991, 3.69774603522003, 0.937919708191361], [4.062103771249795, 0.5573297924174547, None, 2.5367253677148147, 2.461876306528778, 3.8944705387131604, 3.642294982366017, 0.07572861211163406, 1.1898488535035745, 1.0189283288589985, 3.3873772752397873], [4.459386237742376, 0.2920004141387411, 4.111783501318548, None, 4.645251101006911, 0.6338138892201106, 3.015285355927127, 3.8524756003460965, 0.22484947072326067, 1.742369461321163, 4.129817407682388], [1.747914317165551, 3.109219399764456, 4.628388180834865, 1.9987262230920715, None, 3.8482125345870566, 4.264408899797562, 4.52952946900319, 2.6420512870218618, 4.394748528007232, 1.6346739256102927], [4.802246258043724, 0.017273626074775228, 4.477187164963779, 3.9240543880472236, 1.2424155800759813, None, 0.0689824829322977, 2.1473643318238063, 4.42931077219334, 3.6239248331824925, 3.378927719582028], [1.4430923778175608, 4.709036383391366, 1.4456680802919046, 1.6443057629221347, 0.7600423920497762, 1.2125329914433192, None, 2.312600907976547, 4.264589890662854, 1.6275501152171286, 1.701573829051794], [1.4687420650697014, 2.942633234641454, 3.7701489706365225, 4.214073391188645, 0.7948351639469708, 1.6981462693332254, 1.7169163380442636, None, 0.32363885821877714, 4.341424665557067, 0.551027904972114], [0.6210709454757468, 3.557811526109197, 0.42681559731192587, 3.4263103470875094, 4.910661720891846, 0.6875475000662107, 0.20428240049354007, 1.8373103741437335, None, 2.0065530779086584, 2.838491617571309], [3.223715745031128, 1.6470450971861776, 4.09763771210031, 3.9253930530098025, 0.8822068517801201, 1.1958547219147508, 3.8372238433634696, 1.2687391469157276, 4.651363967118531, None, 4.246738093048908], [2.817192423915049, 4.24653229505164, 1.1811847932608792, 2.1972494770541706, 1.2268956544023157, 1.778661272277093, 2.620974049153479, 1.3015469676385882, 2.7454299695985247, 2.9562036553694577, None]]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/4132aaae14cf4a6aac79c65656a0eb5e-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/4132aaae14cf4a6aac79c65656a0eb5e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 128 COLUMNS
# At line 1022 RHS
# At line 1146 BOUNDS
# At line 1278 ENDATA
# Problem MODEL has 123 rows, 131 columns and 521 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 20.318 - 0.00 seconds
# Cgl0002I 11 variables fixed
# Cgl0003I 0 fixed, 10 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 112 rows, 120 columns (120 integer (110 of which binary)) and 490 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 5.32907e-15
# Cbc0038I Solution found of 20.318
# Cbc0038I Cleaned solution of 20.318
# Cbc0038I Before mini branch and bound, 120 integers at bound fixed and 0 continuous of which 5 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 20.318 - took 0.00 seconds
# Cbc0012I Integer solution of 20.317974 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 20.31797385107241, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 20.318 to 20.318
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                20.31797385
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Your code returned tours: [[0, 2, 7], [0, 3, 8], [0, 6], [0, 9, 5, 1], [0, 10, 4]]
# Tour cost obtained by your code: 20.317973851070445
# ------
# Trial # 2
#  n= 9, k=4
# cost_matrix =
# [[None, 3.103312753815187, 4.793059774674414, 1.081742654644076, 2.299716309694169, 4.487870259192591, 2.0515459665861675, 2.9344502303701834, 2.4995208427368913], [3.941829871018533, None, 1.4761804041229376, 3.658333324911137, 2.4246882988276934, 4.817571286527198, 1.1549729800825848, 1.7617403038848112, 1.1782556697857216], [0.1322948948421765, 2.786054838683554, None, 1.586554167862576, 2.1941697387049004, 0.1768590271485565, 3.466164406008556, 4.991523665341301, 1.2453844051948688], [0.8064725585374632, 0.9204893458241475, 4.5880232105926915, None, 4.140892931560313, 3.133471770657537, 1.2949841554195145, 4.335217194659599, 2.4326864220110926], [3.838223490036121, 2.0664747986241405, 1.8220157026871686, 2.7071645879510693, None, 4.749278940466072, 4.3006387355222495, 4.827704257940845, 2.956641692629619], [2.3318721884550673, 3.2199488203179554, 0.40303641178262184, 0.8529548862610364, 1.3064522335016493, None, 0.29407583833423456, 3.614616239046613, 3.1993711232572752], [3.6740441121080707, 2.136192347296699, 0.3781447331645832, 1.042687440392141, 2.336692190455894, 4.862445298662986, None, 1.1407432743709367, 2.9010432027077657], [1.3777774217637355, 0.9140892496324687, 0.8123409013291077, 4.343270165084865, 2.1181631284390874, 0.23359091752035543, 2.2217684069184362, None, 3.923132222403968], [0.07334381829878389, 2.6200192059034726, 3.06084895155375, 0.7997091517732546, 2.33122902387705, 3.1244774832033406, 3.0155906941607844, 4.295765078690716, None]]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/d8a614b1cffa4ca6ab11c7d200abd414-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/d8a614b1cffa4ca6ab11c7d200abd414-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 88 COLUMNS
# At line 676 RHS
# At line 760 BOUNDS
# At line 850 ENDATA
# Problem MODEL has 83 rows, 89 columns and 337 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15.5679 - 0.00 seconds
# Cgl0002I 9 variables fixed
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 74 rows, 80 columns (80 integer (72 of which binary)) and 312 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 2.22045e-15
# Cbc0038I Solution found of 15.5679
# Cbc0038I Cleaned solution of 15.5679
# Cbc0038I Before mini branch and bound, 80 integers at bound fixed and 0 continuous of which 4 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 15.5679 - took 0.00 seconds
# Cbc0012I Integer solution of 15.567905 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 15.56790474052248, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 15.5679 to 15.5679
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                15.56790474
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Your code returned tours: [[0, 3], [0, 4, 1, 8], [0, 6, 2], [0, 7, 5]]
# Tour cost obtained by your code: 15.56790474052289
# ------
# Trial # 3
#  n= 8, k=4
# cost_matrix =
# [[None, 1.358668719724987, 4.364985276664186, 1.9538686101738394, 4.6369450799176635, 0.6796553555351487, 2.7502229104023064, 2.473505718493687], [2.097309360949434, None, 1.247179407909953, 2.384925644323749, 1.5030492522924006, 1.55766364291041, 0.64206188672145, 4.298931670236163], [4.4272441637656605, 4.793032579062578, None, 4.37323517187323, 1.8642169764907086, 4.064806706082537, 2.4837950247499285, 0.0846566092758505], [2.727309931980844, 1.3523340330569473, 0.8395033885176262, None, 1.8023222613773315, 1.049087354839513, 1.1974417824304884, 3.714217826803181], [3.481577279052815, 3.081423572622881, 2.4123637831429896, 4.490335599578394, None, 2.5386918155761955, 3.3089805510000074, 3.562131059888771], [1.1061920853170581, 3.9412131781295368, 0.679814355041673, 1.8091944374527875, 2.690474627658043, None, 4.720895845286571, 3.3620061084119794], [1.6734534266637375, 1.369274086323139, 1.572059914389508, 2.2711201301366173, 4.375010982123176, 0.07200297164731029, None, 0.3694876905935085], [1.3413324525968406, 1.2134019399128837, 0.9103638907439854, 4.174745199250306, 3.2124793130238123, 3.90037253847793, 0.5969719697467135, None]]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/ad83b6f01ee6473eac30a999c264b20f-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/ad83b6f01ee6473eac30a999c264b20f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 71 COLUMNS
# At line 530 RHS
# At line 597 BOUNDS
# At line 669 ENDATA
# Problem MODEL has 66 rows, 71 columns and 260 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 16.7722 - 0.00 seconds
# Cgl0002I 8 variables fixed
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 58 rows, 63 columns (63 integer (56 of which binary)) and 238 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 16.7722
# Cbc0038I Cleaned solution of 16.7722
# Cbc0038I Before mini branch and bound, 63 integers at bound fixed and 0 continuous of which 3 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 16.7722 - took 0.00 seconds
# Cbc0012I Integer solution of 16.77218 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 16.77218008955255, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 16.7722 to 16.7722
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                16.77218009
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Your code returned tours: [[0, 1, 4], [0, 3, 2, 7], [0, 5], [0, 6]]
# Tour cost obtained by your code: 16.77218008955261
# ------
# Trial # 4
#  n= 5, k=2
# cost_matrix =
# [[None, 3.2872577025617344, 0.38304739587479875, 2.420122331190306, 4.356205222904744], [0.7862526525461377, None, 0.4456068915516115, 4.211913061730531, 2.248678188502133], [0.1526718756837281, 2.034516709843996, None, 4.948591216173225, 0.39639449982305786], [4.000358228901522, 4.389058547105019, 2.645688516229701, None, 3.7632958213046757], [4.494684692733257, 1.6773850627654519, 3.4982184753614707, 2.6156068504241947, None]]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/39194c8097fb42c1ab76600c9f7996be-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/39194c8097fb42c1ab76600c9f7996be-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 200 RHS
# At line 228 BOUNDS
# At line 258 ENDATA
# Problem MODEL has 27 rows, 29 columns and 89 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.18278 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 22 rows, 24 columns (24 integer (20 of which binary)) and 76 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 6.66134e-16
# Cbc0038I Solution found of 9.18278
# Cbc0038I Cleaned solution of 9.18278
# Cbc0038I Before mini branch and bound, 24 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 9.18278 - took 0.00 seconds
# Cbc0012I Integer solution of 9.1827751 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 9.182775139364599, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 9.18278 to 9.18278
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                9.18277514
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Your code returned tours: [[0, 2], [0, 3, 4, 1]]
# Tour cost obtained by your code: 9.182775139365098
# ------
# test passed: 15 points

# %% [markdown]
# ## Problem 1 B
#
# Notice that in previous part, it happens that with $k=4$ salespeople, we actually get a worse cost than using $k=3$ people. You can try out a few examples to convince yourself as to why this happens.
#
# We wish to modify the problem to allow salespeople to idle. In other words, although we input $k$ salespeople, the tour we construct may involve $1 \leq l \leq k$ salespeople.
#
# Modify the ILP formulation from the previous problem to solve the problem of up to $k$ people rather than exactly $k$ salespeople. Note that we still require that every vertex be visited exactly once by some salesperson.
#
# Complete the implementation of the function `upto_k_tsp_mtz_encoding(n, k, cost_matrix)` below. It follows the same input convention as previous problem but note that we are now computing a tour with at most $k$ salespeople. In other words, not all salespeople need be employed in the tour.
#
# Your code must return a list `lst` that has less than or equal to  $k$ lists, wherein `lst[j]` represents the locations visited by the $j^{th}$ salesperson.
#
# For Example-1 from the previous part above, for $k=2$ or $k=3$, your code must return
# ~~~
# [ [0, 3, 1, 4, 2] ]
# ~~~
# As it turns out, in this example a single salesperson suffices to yield optimal cost.

# %%
from pulp import *
def upto_k_tsp_mtz_encoding(n, k, cost_matrix):
    # check inputs are OK
    assert 1 <= k < n
    assert len(cost_matrix) == n, f'Cost matrix is not {n}x{n}'
    assert all(len(cj) == n for cj in cost_matrix), f'Cost matrix is not {n}x{n}'
    prob = LpProblem('kTSP', LpMinimize)
    # finish your implementation here
    # your code must return a list of k-lists [ [0, i1, ..., il], [0, j1,...,jl],...] wherein 
    # the ith entry in our list of lists represents the 
    # tour undertaken by the ith salesperson
    # your code here
    res = int(1e9), []
    for i in range(1,k+1):
        val = k_tsp_mtz_encoding(n, i, cost_matrix)
        value = 0
        for i in val:
            value += cost_matrix[i[-1]][0]
            value += cost_matrix[0][i[1]]
            for j in range(1, len(i)):
                value += cost_matrix[i[j-1]][i[j]]
        res = (value, val) if value < res[0] else res
    print(res)
    return res[1]
    raise NotImplementedError

# %%
cost_matrix=[ [None,3,4,3,5],
             [1, None, 2,4, 1],
             [2, 1, None, 5, 4],
             [1, 1, 5, None, 4],
             [2, 1, 3, 5, None] ]
n=5
k=3
all_tours = upto_k_tsp_mtz_encoding(n, k, cost_matrix)
print(f'Your code returned tours: {all_tours}')
assert len(all_tours) <= k, f'<= {k} tours -- your code returns {len(all_tours)} tours instead'

tour_cost = 0
for tour in all_tours:
    assert tour[0] == 0, 'Each salesperson tour must start from vertex 0'
    i = 0
    for j in tour[1:]:
        tour_cost += cost_matrix[i][j]
        i = j
    tour_cost += cost_matrix[i][0]

assert len(all_tours) == 1, f'In this example, just one salesperson is needed to optimally visit all vertices. Your code returns {len(all_tours)}'
print(f'Tour cost obtained by your code: {tour_cost}')
assert abs(tour_cost - 10) <= 0.001, f'Expected tour cost is 10, your code returned {tour_cost}'
for i in range(1, n):
    is_in_tour = [ 1 if i in tour else 0 for tour in all_tours]
    assert sum(is_in_tour) == 1, f' vertex {i} is in {sum(is_in_tour)} tours -- this is incorrect'

print('test passed: 3 points')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/fa2a1b7d12b14058a540f509b6e21536-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/fa2a1b7d12b14058a540f509b6e21536-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 200 RHS
# At line 228 BOUNDS
# At line 258 ENDATA
# Problem MODEL has 27 rows, 29 columns and 89 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.4 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 22 rows, 24 columns (24 integer (20 of which binary)) and 76 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 6 integers unsatisfied sum - 1.2
# Cbc0038I Pass   1: suminf.    1.20000 (6) obj. 9.4 iterations 1
# Cbc0038I Pass   2: suminf.    1.20000 (6) obj. 10.6 iterations 6
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 15 iterations 6
# Cbc0038I Solution found of 15
# Cbc0038I Cleaned solution of 15
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 24 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of 13.5401
# Cbc0038I Pass   4: suminf.    1.20000 (6) obj. 9.4 iterations 0
# Cbc0038I Pass   5: suminf.    1.20000 (6) obj. 10.6 iterations 7
# Cbc0038I Pass   6: suminf.    0.00000 (0) obj. 12 iterations 7
# Cbc0038I Solution found of 12
# Cbc0038I Cleaned solution of 12
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 24 columns, reduced to 8 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 10.6801
# Cbc0038I Reduced cost fixing fixed 7 variables on major pass 3
# Cbc0038I Pass   7: suminf.    1.20000 (6) obj. 9.4 iterations 0
# Cbc0038I Pass   8: suminf.    1.20000 (6) obj. 10.6 iterations 5
# Cbc0038I Pass   9: suminf.    1.20000 (6) obj. 10.6 iterations 0
# Cbc0038I Pass  10: suminf.    1.44024 (11) obj. 10.6801 iterations 2
# Cbc0038I Pass  11: suminf.    1.20000 (6) obj. 10.6 iterations 4
# Cbc0038I Pass  12: suminf.    1.53634 (11) obj. 10.6801 iterations 1
# Cbc0038I Pass  13: suminf.    1.20000 (6) obj. 10.6 iterations 2
# Cbc0038I Pass  14: suminf.    1.20000 (6) obj. 10.6 iterations 1
# Cbc0038I Pass  15: suminf.    1.20000 (6) obj. 10.6 iterations 1
# Cbc0038I Pass  16: suminf.    1.60000 (8) obj. 9.6 iterations 5
# Cbc0038I Pass  17: suminf.    1.60000 (4) obj. 9.6 iterations 3
# Cbc0038I Pass  18: suminf.    0.00000 (0) obj. 10 iterations 3
# Cbc0038I Solution found of 10
# Cbc0038I Cleaned solution of 10
# Cbc0038I Before mini branch and bound, 10 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 10 - took 0.00 seconds
# Cbc0012I Integer solution of 10 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 10, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 10 variables fixed on reduced cost
# Cuts at root node changed objective from 9.4 to 9.4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                10.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/53f9a349076046dd86c7bffac88516e7-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/53f9a349076046dd86c7bffac88516e7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 200 RHS
# At line 228 BOUNDS
# At line 258 ENDATA
# Problem MODEL has 27 rows, 29 columns and 89 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 12 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 22 rows, 24 columns (24 integer (20 of which binary)) and 76 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.6
# Cbc0038I Pass   1: suminf.    1.60000 (8) obj. 12.4 iterations 5
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 14 iterations 7
# Cbc0038I Solution found of 14
# Cbc0038I Cleaned solution of 14
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 24 columns, reduced to 5 rows 6 columns
# Cbc0038I Mini branch and bound improved solution from 14 to 12 (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 12 - took 0.00 seconds
# Cbc0012I Integer solution of 12 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 12, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 12 to 12
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                12.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/769d85f0539d469b85964cd7234edcb3-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/769d85f0539d469b85964cd7234edcb3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 200 RHS
# At line 228 BOUNDS
# At line 258 ENDATA
# Problem MODEL has 27 rows, 29 columns and 89 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 16 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 13 rows, 16 columns (16 integer (12 of which binary)) and 48 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 2.22045e-16
# Cbc0038I Solution found of 16
# Cbc0038I Cleaned solution of 16
# Cbc0038I Before mini branch and bound, 16 integers at bound fixed and 0 continuous of which 1 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 16 - took 0.00 seconds
# Cbc0012I Integer solution of 16 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 16, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 16 to 16
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                16.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# (13, [[0, 3, 1, 4, 2]])
# Your code returned tours: [[0, 3, 1, 4, 2]]
# Tour cost obtained by your code: 10
# test passed: 3 points

# %%
cost_matrix = [ 
 [None, 1, 1, 1, 1, 1, 1, 1],
    [0, None, 1, 2, 1, 1, 1, 1],
    [1, 0, None, 1, 2, 2, 2, 1],
    [1, 2, 2, None, 0, 1, 2, 1],
    [1, 1, 1, 1, None, 1, 1, 1],
    [0,  1, 2, 1, 1, None, 1, 1],
    [1, 0,  1, 2, 2, 2,None, 1],
    [1, 2, 2, 0, 1, 2, 1, None],
]
n = 8
k = 5

all_tours = upto_k_tsp_mtz_encoding(n, k, cost_matrix)
print(f'Your code returned tours: {all_tours}')
assert len(all_tours) <= k, f'k={k} must yield two tours -- your code returns {len(all_tours)} tours instead'

tour_cost = 0
for tour in all_tours:
    assert tour[0] == 0, 'Each salesperson tour must start from vertex 0'
    i = 0
    for j in tour[1:]:
        tour_cost += cost_matrix[i][j]
        i = j
    tour_cost += cost_matrix[i][0]

print(f'Tour cost obtained by your code: {tour_cost}')
assert abs(tour_cost - 4) <= 0.001, f'Expected tour cost is 4, your code returned {tour_cost}'
for i in range(1, n):
    is_in_tour = [ 1 if i in tour else 0 for tour in all_tours]
    assert sum(is_in_tour) == 1, f' vertex {i} is in {sum(is_in_tour)} tours -- this is incorrect'

print('test passed: 3 points')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/fac2da2e1ef6470ea118e334c18e8010-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/fac2da2e1ef6470ea118e334c18e8010-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 71 COLUMNS
# At line 524 RHS
# At line 591 BOUNDS
# At line 663 ENDATA
# Problem MODEL has 66 rows, 71 columns and 260 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4 - 0.00 seconds
# Cgl0002I 8 variables fixed
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 58 rows, 63 columns (63 integer (56 of which binary)) and 238 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 9 integers unsatisfied sum - 2.25
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 4 iterations 13
# Cbc0038I Solution found of 4
# Cbc0038I Cleaned solution of 4
# Cbc0038I Before mini branch and bound, 48 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 4 - took 0.00 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4 to 4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/cff054edd0cb41e999c89cd3cc028d58-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/cff054edd0cb41e999c89cd3cc028d58-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 71 COLUMNS
# At line 524 RHS
# At line 591 BOUNDS
# At line 663 ENDATA
# Problem MODEL has 66 rows, 71 columns and 260 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4 - 0.00 seconds
# Cgl0002I 8 variables fixed
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 58 rows, 63 columns (63 integer (56 of which binary)) and 238 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 9 integers unsatisfied sum - 2.25
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 4 iterations 8
# Cbc0038I Solution found of 4
# Cbc0038I Cleaned solution of 4
# Cbc0038I Before mini branch and bound, 51 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 4 - took 0.00 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4 to 4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/b548add1c2214d93995e03fd367a235d-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/b548add1c2214d93995e03fd367a235d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 71 COLUMNS
# At line 524 RHS
# At line 591 BOUNDS
# At line 663 ENDATA
# Problem MODEL has 66 rows, 71 columns and 260 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 5 - 0.00 seconds
# Cgl0002I 8 variables fixed
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 58 rows, 63 columns (63 integer (56 of which binary)) and 238 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 10 integers unsatisfied sum - 2
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 5 iterations 8
# Cbc0038I Solution found of 5
# Cbc0038I Cleaned solution of 5
# Cbc0038I Before mini branch and bound, 51 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 5 - took 0.00 seconds
# Cbc0012I Integer solution of 5 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 5, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 5 to 5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/93082058ee604746a74a7851f0f28d11-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/93082058ee604746a74a7851f0f28d11-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 71 COLUMNS
# At line 524 RHS
# At line 591 BOUNDS
# At line 663 ENDATA
# Problem MODEL has 66 rows, 71 columns and 260 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6 - 0.00 seconds
# Cgl0002I 8 variables fixed
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 58 rows, 63 columns (63 integer (56 of which binary)) and 238 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 4 integers unsatisfied sum - 0.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 6 iterations 3
# Cbc0038I Solution found of 6
# Cbc0038I Cleaned solution of 6
# Cbc0038I Before mini branch and bound, 58 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 6 - took 0.00 seconds
# Cbc0012I Integer solution of 6 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 6, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6 to 6
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/ae777cb8d4434521b5e25b773abac1a2-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/ae777cb8d4434521b5e25b773abac1a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 71 COLUMNS
# At line 524 RHS
# At line 591 BOUNDS
# At line 663 ENDATA
# Problem MODEL has 66 rows, 71 columns and 260 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 8 - 0.00 seconds
# Cgl0002I 8 variables fixed
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 58 rows, 63 columns (63 integer (56 of which binary)) and 238 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 10 integers unsatisfied sum - 1.25
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 8 iterations 6
# Cbc0038I Solution found of 8
# Cbc0038I Cleaned solution of 8
# Cbc0038I Before mini branch and bound, 51 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 8 - took 0.00 seconds
# Cbc0012I Integer solution of 8 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 8, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 8 to 8
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                8.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# (5, [[0, 6, 2, 1, 7, 3, 4, 5]])
# Your code returned tours: [[0, 6, 2, 1, 7, 3, 4, 5]]
# Tour cost obtained by your code: 4
# test passed: 3 points

# %%
from random import uniform, randint

def create_cost(n):
    return [ [uniform(0, 5) if i != j else None for j in range(n)] for i in range(n)]

for trial in range(20):
    print(f'Trial # {trial}')
    n = randint(5, 11)
    k = randint(2, n//2)
    print(f' n= {n}, k={k}')
    cost_matrix = create_cost(n)
    print('cost_matrix = ')
    print(cost_matrix)
    all_tours = upto_k_tsp_mtz_encoding(n, k, cost_matrix)
    print(f'Your code returned tours: {all_tours}')
    assert len(all_tours) <= k, f'k={k} must yield two tours -- your code returns {len(all_tours)} tours instead'

    tour_cost = 0
    for tour in all_tours:
        assert tour[0] == 0, 'Each salesperson tour must start from vertex 0'
        i = 0
        for j in tour[1:]:
            tour_cost += cost_matrix[i][j]
            i = j
        tour_cost += cost_matrix[i][0]

    print(f'Tour cost obtained by your code: {tour_cost}')
    #assert abs(tour_cost - 6) <= 0.001, f'Expected tour cost is 6, your code returned {tour_cost}'
    for i in range(1, n):
        is_in_tour = [ 1 if i in tour else 0 for tour in all_tours]
        assert sum(is_in_tour) == 1, f' vertex {i} is in {sum(is_in_tour)} tours -- this is incorrect'
    print('------')
print('test passed: 4 points')
# Out:
# Trial # 0
#  n= 7, k=3
# cost_matrix =
# [[None, 3.6834164204008033, 3.272155991982506, 1.3354297711555403, 4.145752597555902, 0.22669276913058478, 4.180232420146122], [0.9460131817110107, None, 3.684038578499802, 4.093408504273987, 2.312195226502039, 4.931064028793817, 0.05208771623483821], [3.1557910369514586, 1.416444178685166, None, 2.158863140404404, 0.982627496159405, 2.09166989445245, 3.792975939025134], [1.8784992673257732, 1.8929298070524114, 1.708620595660214, None, 4.298122784129902, 3.330323726515335, 2.667904838236383], [4.7742912185631035, 1.686217368024926, 4.710558432856036, 1.8900462768273474, None, 2.101520074276777, 1.1356791262130046], [1.5529719716562744, 4.8695401919549415, 1.51257211736482, 4.855670164269723, 3.543640992933057, None, 0.5740731732053966], [2.4249672967042617, 4.9734551500417075, 4.676834253623373, 1.2565423997958987, 0.9299142651681525, 2.2451760887939063, None]]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/463f8d9ca9c445f3b107ce7e5395d0a5-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/463f8d9ca9c445f3b107ce7e5395d0a5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 56 COLUMNS
# At line 402 RHS
# At line 454 BOUNDS
# At line 510 ENDATA
# Problem MODEL has 51 rows, 55 columns and 193 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.38079 - 0.00 seconds
# Cgl0002I 7 variables fixed
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 44 rows, 48 columns (48 integer (42 of which binary)) and 174 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 5.77316e-15
# Cbc0038I Solution found of 7.38079
# Cbc0038I Cleaned solution of 7.38079
# Cbc0038I Before mini branch and bound, 48 integers at bound fixed and 0 continuous of which 5 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 7.38079 - took 0.00 seconds
# Cbc0012I Integer solution of 7.380787 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 7.3807869836874, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 7.38079 to 7.38079
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.38078698
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/cf7a9e543a0b43bd871bda163d49542c-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/cf7a9e543a0b43bd871bda163d49542c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 56 COLUMNS
# At line 402 RHS
# At line 454 BOUNDS
# At line 510 ENDATA
# Problem MODEL has 51 rows, 55 columns and 193 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.34218 - 0.00 seconds
# Cgl0002I 7 variables fixed
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 44 rows, 48 columns (48 integer (42 of which binary)) and 174 elements
# Cbc0038I Initial state - 8 integers unsatisfied sum - 1.14286
# Cbc0038I Pass   1: suminf.    1.14286 (8) obj. 10.7194 iterations 9
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 19.5254 iterations 7
# Cbc0038I Solution found of 19.5254
# Cbc0038I Cleaned solution of 19.5254
# Cbc0038I Before mini branch and bound, 31 integers at bound fixed and 0 continuous of which 1 were internal integer and 0 internal continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 4 rows 3 columns
# Cbc0038I Mini branch and bound improved solution from 19.5254 to 14.6373 (0.01 seconds)
# Cbc0038I Round again with cutoff of 14.1078
# Cbc0038I Reduced cost fixing fixed 2 variables on major pass 2
# Cbc0038I Pass   3: suminf.    1.14286 (8) obj. 10.7194 iterations 0
# Cbc0038I Pass   4: suminf.    3.78135 (8) obj. 14.1078 iterations 7
# Cbc0038I Pass   5: suminf.    3.21047 (7) obj. 14.1078 iterations 10
# Cbc0038I Pass   6: suminf.    0.00000 (0) obj. 12.113 iterations 15
# Cbc0038I Solution found of 12.113
# Cbc0038I Cleaned solution of 12.113
# Cbc0038I Before mini branch and bound, 25 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 11 rows 10 columns
# Cbc0038I Mini branch and bound improved solution from 12.113 to 9.88464 (0.02 seconds)
# Cbc0038I Round again with cutoff of 9.77614
# Cbc0038I Reduced cost fixing fixed 26 variables on major pass 3
# Cbc0038I Pass   7: suminf.    1.14286 (8) obj. 9.34218 iterations 6
# Cbc0038I Pass   8: suminf.    1.97180 (10) obj. 9.77614 iterations 7
# Cbc0038I Pass   9: suminf.    1.97180 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  10: suminf.    1.97180 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  11: suminf.    1.97180 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  12: suminf.    1.97180 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  13: suminf.    1.97180 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  14: suminf.    2.26952 (9) obj. 9.77614 iterations 2
# Cbc0038I Pass  15: suminf.    2.26952 (9) obj. 9.77614 iterations 0
# Cbc0038I Pass  16: suminf.    2.26952 (9) obj. 9.77614 iterations 0
# Cbc0038I Pass  17: suminf.    2.26952 (9) obj. 9.77614 iterations 0
# Cbc0038I Pass  18: suminf.    1.14286 (8) obj. 9.34218 iterations 6
# Cbc0038I Pass  19: suminf.    1.14286 (8) obj. 9.34218 iterations 1
# Cbc0038I Pass  20: suminf.    1.14286 (8) obj. 9.34218 iterations 1
# Cbc0038I Pass  21: suminf.    1.97180 (10) obj. 9.77614 iterations 7
# Cbc0038I Pass  22: suminf.    1.97180 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  23: suminf.    1.97180 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  24: suminf.    1.97180 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  25: suminf.    3.13785 (12) obj. 9.77614 iterations 3
# Cbc0038I Pass  26: suminf.    1.42857 (10) obj. 9.45316 iterations 2
# Cbc0038I Pass  27: suminf.    1.14286 (8) obj. 9.48379 iterations 4
# Cbc0038I Pass  28: suminf.    3.74835 (9) obj. 9.77614 iterations 3
# Cbc0038I Pass  29: suminf.    3.15538 (13) obj. 9.77614 iterations 4
# Cbc0038I Pass  30: suminf.    1.97180 (10) obj. 9.77614 iterations 1
# Cbc0038I Pass  31: suminf.    1.97180 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  32: suminf.    1.97180 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  33: suminf.    4.04681 (10) obj. 9.77614 iterations 5
# Cbc0038I Pass  34: suminf.    4.04681 (10) obj. 9.77614 iterations 1
# Cbc0038I Pass  35: suminf.    4.04681 (10) obj. 9.77614 iterations 0
# Cbc0038I Pass  36: suminf.    1.14286 (8) obj. 9.48379 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 31 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of 9.88464 - took 0.01 seconds
# Cbc0012I Integer solution of 9.8846417 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 44 rows 48 columns, reduced to 5 rows 3 columns
# Cbc0031I 1 added rows had average density of 2
# Cbc0013I At root node, 27 cuts changed objective from 9.3421767 to 9.969615 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 8 row cuts average 2.0 elements, 2 column cuts (2 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 14 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 2.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 9.8846416517514, took 1 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 26 variables fixed on reduced cost
# Cuts at root node changed objective from 9.34218 to 9.96961
# Probing was tried 1 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 14 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                9.88464165
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/fcc03c28464e4bf782c1f3183ccff720-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/fcc03c28464e4bf782c1f3183ccff720-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 56 COLUMNS
# At line 402 RHS
# At line 454 BOUNDS
# At line 510 ENDATA
# Problem MODEL has 51 rows, 55 columns and 193 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 12.7842 - 0.00 seconds
# Cgl0002I 7 variables fixed
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 44 rows, 48 columns (48 integer (42 of which binary)) and 174 elements
# Cbc0038I Initial state - 8 integers unsatisfied sum - 1.14286
# Cbc0038I Pass   1: suminf.    1.14286 (4) obj. 13.9589 iterations 11
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 17.1218 iterations 6
# Cbc0038I Solution found of 17.1218
# Cbc0038I Cleaned solution of 17.1218
# Cbc0038I Before mini branch and bound, 34 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 9 rows 7 columns
# Cbc0038I Mini branch and bound improved solution from 17.1218 to 13.3267 (0.01 seconds)
# Cbc0038I Round again with cutoff of 13.2724
# Cbc0038I Reduced cost fixing fixed 28 variables on major pass 2
# Cbc0038I Pass   3: suminf.    1.14286 (8) obj. 12.7842 iterations 4
# Cbc0038I Pass   4: suminf.    1.68583 (11) obj. 13.2724 iterations 8
# Cbc0038I Pass   5: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass   6: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass   7: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass   8: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass   9: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass  10: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass  11: suminf.    1.14286 (8) obj. 12.7964 iterations 5
# Cbc0038I Pass  12: suminf.    1.14286 (8) obj. 12.7842 iterations 1
# Cbc0038I Pass  13: suminf.    1.14286 (8) obj. 12.7842 iterations 0
# Cbc0038I Pass  14: suminf.    1.14286 (8) obj. 12.7842 iterations 0
# Cbc0038I Pass  15: suminf.    1.14286 (8) obj. 12.7842 iterations 0
# Cbc0038I Pass  16: suminf.    1.68583 (11) obj. 13.2724 iterations 4
# Cbc0038I Pass  17: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass  18: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass  19: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass  20: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass  21: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass  22: suminf.    1.14286 (8) obj. 12.7842 iterations 5
# Cbc0038I Pass  23: suminf.    1.14286 (8) obj. 12.7842 iterations 0
# Cbc0038I Pass  24: suminf.    1.68583 (11) obj. 13.2724 iterations 4
# Cbc0038I Pass  25: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass  26: suminf.    1.14286 (8) obj. 12.7842 iterations 5
# Cbc0038I Pass  27: suminf.    1.68583 (11) obj. 13.2724 iterations 5
# Cbc0038I Pass  28: suminf.    1.68583 (11) obj. 13.2724 iterations 0
# Cbc0038I Pass  29: suminf.    1.14286 (8) obj. 12.7842 iterations 5
# Cbc0038I Pass  30: suminf.    1.14286 (8) obj. 12.7842 iterations 0
# Cbc0038I Pass  31: suminf.    1.14286 (8) obj. 12.7842 iterations 0
# Cbc0038I Pass  32: suminf.    1.14286 (8) obj. 12.7842 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 35 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 9 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 13.3267 - took 0.01 seconds
# Cbc0012I Integer solution of 13.326676 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 44 rows 48 columns, reduced to 5 rows 3 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 12.784211 to 12.784211 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 13.3266763154004, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 28 variables fixed on reduced cost
# Cuts at root node changed objective from 12.7842 to 12.7842
# Probing was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                13.32667632
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# (7.607479752818021, [[0, 5, 6, 3, 2, 4, 1]])
# Your code returned tours: [[0, 5, 6, 3, 2, 4, 1]]
# Tour cost obtained by your code: 7.380786983687436
# ------
# Trial # 1
#  n= 7, k=2
# cost_matrix =
# [[None, 1.0135083148245112, 2.2375332456169303, 3.401757139548569, 1.3934400289337312, 4.349682987636135, 2.261668708185229], [1.8721535860603056, None, 2.423696473828174, 3.2565709574676696, 0.961726087274461, 4.798993815924188, 0.5724470856240255], [4.34717654924201, 3.2293993775705943, None, 3.824777664037571, 1.4709770460370737, 4.531964235365862, 0.07517259705339119], [0.5777485522225595, 4.18162332763546, 4.4362771699822865, None, 3.6189019580872, 4.71712187257311, 4.081291131222806], [2.9006071693356006, 0.24433960442646174, 0.839667381145805, 0.11969687255830364, None, 2.9685386812033765, 2.2091611363910406], [3.272860348408998, 3.210501308344279, 0.5693086925483964, 3.6743465362881036, 4.043539364234043, None, 3.3926760003885676], [3.795805905258643, 0.5417900829449501, 4.081854556565518, 4.068696366348103, 3.007743173367179, 0.3542533618026905, None]]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/9ec063bd2e0543178a6c62ab10502d94-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/9ec063bd2e0543178a6c62ab10502d94-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 56 COLUMNS
# At line 402 RHS
# At line 454 BOUNDS
# At line 510 ENDATA
# Problem MODEL has 51 rows, 55 columns and 193 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4.10278 - 0.00 seconds
# Cgl0002I 7 variables fixed
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 44 rows, 48 columns (48 integer (42 of which binary)) and 174 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.71429
# Cbc0038I Pass   1: suminf.    0.85714 (6) obj. 5.24395 iterations 8
# Cbc0038I Pass   2: suminf.    0.85714 (6) obj. 13.1066 iterations 7
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 18.6338 iterations 12
# Cbc0038I Solution found of 18.6338
# Cbc0038I Cleaned solution of 18.6338
# Cbc0038I Before mini branch and bound, 31 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 14 rows 10 columns
# Cbc0038I Mini branch and bound improved solution from 18.6338 to 4.67794 (0.01 seconds)
# Cbc0038I Round again with cutoff of 4.62042
# Cbc0038I Reduced cost fixing fixed 30 variables on major pass 2
# Cbc0038I Pass   4: suminf.    1.71429 (4) obj. 4.10278 iterations 5
# Cbc0038I Pass   5: suminf.    1.82854 (9) obj. 4.62042 iterations 8
# Cbc0038I Pass   6: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass   7: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass   8: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass   9: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  10: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  11: suminf.    1.71429 (4) obj. 4.10278 iterations 3
# Cbc0038I Pass  12: suminf.    1.82854 (9) obj. 4.62042 iterations 3
# Cbc0038I Pass  13: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  14: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  15: suminf.    1.71429 (4) obj. 4.10278 iterations 3
# Cbc0038I Pass  16: suminf.    1.71429 (4) obj. 4.10278 iterations 0
# Cbc0038I Pass  17: suminf.    1.71429 (4) obj. 4.10278 iterations 0
# Cbc0038I Pass  18: suminf.    1.71429 (4) obj. 4.10278 iterations 0
# Cbc0038I Pass  19: suminf.    1.82854 (9) obj. 4.62042 iterations 3
# Cbc0038I Pass  20: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  21: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  22: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  23: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  24: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  25: suminf.    1.71429 (4) obj. 4.10278 iterations 3
# Cbc0038I Pass  26: suminf.    1.82854 (9) obj. 4.62042 iterations 3
# Cbc0038I Pass  27: suminf.    1.71429 (4) obj. 4.10278 iterations 3
# Cbc0038I Pass  28: suminf.    1.82854 (9) obj. 4.62042 iterations 3
# Cbc0038I Pass  29: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  30: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  31: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  32: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I Pass  33: suminf.    1.82854 (9) obj. 4.62042 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 30 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 4.67794 - took 0.01 seconds
# Cbc0012I Integer solution of 4.6779399 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 44 rows 48 columns, reduced to 5 rows 4 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 4.1027825 to 4.1027825 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 4.677939925617999, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 30 variables fixed on reduced cost
# Cuts at root node changed objective from 4.10278 to 4.10278
# Probing was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.67793993
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/fdfe9832cf4248db8a92231eca09b29a-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/fdfe9832cf4248db8a92231eca09b29a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 56 COLUMNS
# At line 402 RHS
# At line 454 BOUNDS
# At line 510 ENDATA
# Problem MODEL has 51 rows, 55 columns and 193 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.75608 - 0.00 seconds
# Cgl0002I 7 variables fixed
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 44 rows, 48 columns (48 integer (42 of which binary)) and 174 elements
# Cbc0038I Initial state - 9 integers unsatisfied sum - 2.21429
# Cbc0038I Pass   1: suminf.    0.85714 (6) obj. 7.54782 iterations 7
# Cbc0038I Pass   2: suminf.    0.85714 (6) obj. 15.4105 iterations 7
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 20.9376 iterations 12
# Cbc0038I Solution found of 20.9376
# Cbc0038I Cleaned solution of 20.9376
# Cbc0038I Before mini branch and bound, 30 integers at bound fixed and 0 continuous of which 1 were internal integer and 0 internal continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 13 rows 11 columns
# Cbc0038I Mini branch and bound improved solution from 20.9376 to 8.94758 (0.01 seconds)
# Cbc0038I Round again with cutoff of 8.72842
# Cbc0038I Reduced cost fixing fixed 13 variables on major pass 2
# Cbc0038I Pass   4: suminf.    1.14286 (8) obj. 7.58575 iterations 3
# Cbc0038I Pass   5: suminf.    2.24422 (9) obj. 8.72842 iterations 8
# Cbc0038I Pass   6: suminf.    2.89578 (11) obj. 8.72842 iterations 5
# Cbc0038I Pass   7: suminf.    1.95536 (8) obj. 8.72842 iterations 6
# Cbc0038I Pass   8: suminf.    1.95536 (8) obj. 8.72842 iterations 0
# Cbc0038I Pass   9: suminf.    1.95536 (8) obj. 8.72842 iterations 1
# Cbc0038I Pass  10: suminf.    1.95536 (8) obj. 8.72842 iterations 1
# Cbc0038I Pass  11: suminf.    1.95536 (8) obj. 8.72842 iterations 0
# Cbc0038I Pass  12: suminf.    0.22441 (7) obj. 8.72842 iterations 8
# Cbc0038I Pass  13: suminf.    0.00000 (0) obj. 8.6125 iterations 5
# Cbc0038I Solution found of 8.6125
# Cbc0038I Cleaned solution of 8.6125
# Cbc0038I Before mini branch and bound, 23 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 10 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 8.24121
# Cbc0038I Reduced cost fixing fixed 18 variables on major pass 3
# Cbc0038I Pass  14: suminf.    1.14286 (8) obj. 7.21696 iterations 1
# Cbc0038I Pass  15: suminf.    2.08560 (8) obj. 8.24121 iterations 6
# Cbc0038I Pass  16: suminf.    0.00000 (0) obj. 8.23932 iterations 10
# Cbc0038I Solution found of 8.23932
# Cbc0038I Cleaned solution of 8.23932
# Cbc0038I Before mini branch and bound, 30 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 7.79434
# Cbc0038I Reduced cost fixing fixed 26 variables on major pass 4
# Cbc0038I Pass  17: suminf.    1.71429 (4) obj. 6.94558 iterations 6
# Cbc0038I Pass  18: suminf.    1.53775 (6) obj. 7.79434 iterations 2
# Cbc0038I Pass  19: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  20: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  21: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  22: suminf.    2.21429 (9) obj. 6.75608 iterations 3
# Cbc0038I Pass  23: suminf.    2.57143 (6) obj. 7.10552 iterations 3
# Cbc0038I Pass  24: suminf.    1.71429 (4) obj. 6.94558 iterations 3
# Cbc0038I Pass  25: suminf.    1.71429 (4) obj. 6.94558 iterations 0
# Cbc0038I Pass  26: suminf.    1.53775 (6) obj. 7.79434 iterations 2
# Cbc0038I Pass  27: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  28: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  29: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  30: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  31: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  32: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  33: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  34: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  35: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  36: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  37: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  38: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  39: suminf.    1.53775 (6) obj. 7.79434 iterations 0
# Cbc0038I Pass  40: suminf.    1.53775 (6) obj. 7.79434 iterations 1
# Cbc0038I Pass  41: suminf.    2.20473 (8) obj. 7.79434 iterations 4
# Cbc0038I Pass  42: suminf.    2.20473 (8) obj. 7.79434 iterations 1
# Cbc0038I Pass  43: suminf.    2.20473 (8) obj. 7.79434 iterations 0
# Cbc0038I Pass  44: suminf.    2.20473 (8) obj. 7.79434 iterations 0
# Cbc0038I Pass  45: suminf.    1.71429 (4) obj. 6.94558 iterations 4
# Cbc0038I Pass  46: suminf.    1.71429 (4) obj. 6.94558 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 33 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 44 rows 48 columns, reduced to 8 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 8.23932 - took 0.01 seconds
# Cbc0012I Integer solution of 8.2393151 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 6.756084 to 6.756084 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 8 column cuts (8 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 8.239315134239, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 18 variables fixed on reduced cost
# Cuts at root node changed objective from 6.75608 to 6.75608
# Probing was tried 1 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                8.23931513
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# (5.691448240442073, [[0, 1, 6, 5, 2, 4, 3]])
# Your code returned tours: [[0, 1, 6, 5, 2, 4, 3]]
# Tour cost obtained by your code: 4.677939925617561
# ------
# Trial # 2
#  n= 10, k=2
# cost_matrix =
# [[None, 2.5874062666203272, 3.4970636906301715, 0.9503855992213411, 0.6956517573860571, 1.0075999031246825, 0.2786458365377975, 0.5632578569202923, 4.962120208195292, 0.4658406222037087], [0.9863468089654154, None, 1.8600494118413784, 0.36225916659679946, 1.6106722425604252, 2.378194930966204, 4.928259539109952, 3.5839629794536703, 2.0454164685010117, 3.4364798985099205], [1.1304280886749445, 0.31856706002894475, None, 4.319520594646232, 0.25060206858427025, 3.189231300362367, 0.1394676527812888, 2.1236853392720665, 1.9470245233999595, 3.307776293352367], [0.979981797292846, 2.7099797314670413, 3.0053563541405524, None, 4.085198442345183, 4.902827496547737, 3.1860850290284737, 4.323403697156893, 2.270966635242173, 1.2264185104934555], [4.399336204311639, 0.5912017694482347, 2.3909711959098527, 0.4213946211029751, None, 2.5748452184135164, 0.8331053533274985, 1.3376682266127804, 2.6895871191118745, 1.724693912596037], [4.216834560644145e-05, 0.47989439679574863, 3.483963789567942, 0.21245421479368143, 3.514539371869069, None, 2.6091284524614355, 1.7945114052198181, 3.9593968605711085, 0.17406433069829585], [4.189281217770715, 3.6987017279569567, 1.0339255127032283, 0.4737110040291398, 3.7066955399516983, 1.9582768792457266, None, 0.31697186286120504, 1.08849495493487, 3.5362838458414583], [2.9318561374890635, 0.8480041613704531, 0.9860762930151545, 1.4550047068575955, 4.791462189396208, 3.82224025576331, 3.4690329110506672, None, 3.229099236024629, 1.2533597571509947], [2.8935358426069095, 0.5184753907944067, 4.145969180404979, 3.82173078014503, 1.014322885313379, 0.9298440387750295, 0.7530796722066957, 3.872625038787096, None, 1.6136266360384377], [4.872756020078523, 0.9489832748268634, 1.447244547167748, 1.0708166130760266, 1.1471281046528192, 3.5838543561147542, 2.158313231957721, 3.8954420186608907, 2.6811097771924013, None]]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/2d20c96db6eb47a18eade8c0f590afa0-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/2d20c96db6eb47a18eade8c0f590afa0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 107 COLUMNS
# At line 840 RHS
# At line 943 BOUNDS
# At line 1053 ENDATA
# Problem MODEL has 102 rows, 109 columns and 424 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.96178 - 0.00 seconds
# Cgl0002I 10 variables fixed
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 92 rows, 99 columns (99 integer (90 of which binary)) and 396 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 8.65974e-15
# Cbc0038I Solution found of 6.96178
# Cbc0038I Cleaned solution of 6.96178
# Cbc0038I Before mini branch and bound, 99 integers at bound fixed and 0 continuous of which 8 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 6.96178 - took 0.00 seconds
# Cbc0012I Integer solution of 6.961776 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 6.961775965115901, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6.96178 to 6.96178
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.96177597
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/eb2be9cd91c8405e8b86d47aaf48478b-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/eb2be9cd91c8405e8b86d47aaf48478b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 107 COLUMNS
# At line 840 RHS
# At line 943 BOUNDS
# At line 1053 ENDATA
# Problem MODEL has 102 rows, 109 columns and 424 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.25359 - 0.00 seconds
# Cgl0002I 10 variables fixed
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 92 rows, 99 columns (99 integer (90 of which binary)) and 396 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 3.9968e-15
# Cbc0038I Solution found of 7.25359
# Cbc0038I Cleaned solution of 7.25359
# Cbc0038I Before mini branch and bound, 99 integers at bound fixed and 0 continuous of which 7 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 7.25359 - took 0.00 seconds
# Cbc0012I Integer solution of 7.2535944 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 7.253594424966908, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 7.25359 to 7.25359
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.25359442
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# (7.5250338220359225, [[0, 7, 2, 6, 8, 5, 9, 4, 1, 3]])
# Your code returned tours: [[0, 7, 2, 6, 8, 5, 9, 4, 1, 3]]
# Tour cost obtained by your code: 6.9617759651156295
# ------
# Trial # 3
#  n= 7, k=3
# cost_matrix =
# [[None, 1.3824728615721211, 3.192652611049689, 2.128858733089321, 3.0136605974595905, 1.4785178823358387, 0.33817679683431134], [3.552426779738471, None, 1.695425201652847, 1.2737222723366997, 1.10620384256163, 2.459445264780053, 2.416067223163764], [3.861195389613497, 4.205919136382109, None, 4.994864586902474, 3.592086945578496, 0.05506510761173311, 4.885430685471122], [0.4138519669113849, 2.4167345337623907, 4.056320497885517, None, 1.985071804128982, 1.992637456673339, 3.7745122966570213], [1.3664370353734006, 4.446263296260443, 0.7973281404649979, 4.672268861491636, None, 4.7249113734600465, 3.472562023602954], [2.309634062001397, 2.6593813302020726, 4.065182893506459, 4.089814824807256, 3.907932790551913, None, 2.6195562242295316], [2.5484887463057087, 1.5682768984589828, 0.8380199257856658, 3.606609952156335, 1.1222951684269322, 0.4001688433719486, None]]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/dec8032d41aa45eeac2dbf87d07b9402-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/dec8032d41aa45eeac2dbf87d07b9402-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 56 COLUMNS
# At line 402 RHS
# At line 454 BOUNDS
# At line 510 ENDATA
# Problem MODEL has 51 rows, 55 columns and 193 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.65982 - 0.00 seconds
# Cgl0002I 7 variables fixed
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 44 rows, 48 columns (48 integer (42 of which binary)) and 174 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 5.77316e-15
# Cbc0038I Solution found of 6.65982
# Cbc0038I Cleaned solution of 6.65982
# Cbc0038I Before mini branch and bound, 48 integers at bound fixed and 0 continuous of which 5 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 6.65982 - took 0.00 seconds
# Cbc0012I Integer solution of 6.6598208 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 6.659820782788429, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6.65982 to 6.65982
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.65982078
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/a3c1d99b64994fd1999ac8978d1ddbb9-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/a3c1d99b64994fd1999ac8978d1ddbb9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 56 COLUMNS
# At line 402 RHS
# At line 454 BOUNDS
# At line 510 ENDATA
# Problem MODEL has 51 rows, 55 columns and 193 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.69255 - 0.00 seconds
# Cgl0002I 7 variables fixed
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 44 rows, 48 columns (48 integer (42 of which binary)) and 174 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 2.66454e-15
# Cbc0038I Solution found of 7.69255
# Cbc0038I Cleaned solution of 7.69255
# ...
# Cbc0038I Initial state - 0 integers unsatisfied sum - 3.90799e-14
# Cbc0038I Solution found of 7.36722
# Cbc0038I Cleaned solution of 7.36722
# Cbc0038I Before mini branch and bound, 120 integers at bound fixed and 0 continuous of which 9 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 7.36722 - took 0.00 seconds
# Cbc0012I Integer solution of 7.3672214 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 7.367221379000849, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 7.36722 to 7.36722
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.36722138
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/98bd07cd4df74c9db69dfb0895414e78-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/98bd07cd4df74c9db69dfb0895414e78-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 128 COLUMNS
# At line 1022 RHS
# At line 1146 BOUNDS
# At line 1278 ENDATA
# Problem MODEL has 123 rows, 131 columns and 521 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.2859 - 0.00 seconds
# Cgl0002I 11 variables fixed
# Cgl0003I 0 fixed, 10 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 112 rows, 120 columns (120 integer (110 of which binary)) and 490 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 1.86517e-14
# Cbc0038I Solution found of 9.2859
# Cbc0038I Cleaned solution of 9.2859
# Cbc0038I Before mini branch and bound, 120 integers at bound fixed and 0 continuous of which 8 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 9.2859 - took 0.00 seconds
# Cbc0012I Integer solution of 9.2859013 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 9.285901267366189, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 9.2859 to 9.2859
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                9.28590127
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# (7.393961916558921, [[0, 4, 6, 1, 9, 2, 3, 7, 10, 5, 8]])
# Your code returned tours: [[0, 4, 6, 1, 9, 2, 3, 7, 10, 5, 8]]
# Tour cost obtained by your code: 7.3672213790005
# ------
# Trial # 19
#  n= 9, k=3
# cost_matrix =
# [[None, 0.5119520420277918, 0.1216556842255806, 4.8885023626717645, 1.9651660792074044, 0.6330959192700214, 4.158296178803722, 4.970647809559197, 2.969545755789807], [3.1522712337209793, None, 4.3352065516942, 0.8086856427910466, 3.7841348209391272, 4.64127009128564, 0.44032392293184786, 4.6641261158153515, 1.52864781073992], [1.4133126991527263, 2.277502859521878, None, 0.8109424996012743, 0.13054785234295596, 1.3117409224993475, 4.125358874688973, 3.2071650473323987, 2.2602213096205843], [4.311411232891479, 4.176226677500356, 4.315995651502066, None, 0.5383533577312732, 1.478897142472872, 2.3190186398046455, 1.0510639834249536, 0.8870612011242829], [1.2299489719382117, 4.28304622508813, 3.877040998981932, 0.14571492340991476, None, 1.1148448280296703, 1.056325113263895, 0.40606591624334387, 2.4106595121551333], [2.7258865247484936, 2.1806757855925163, 1.1789621774521453, 1.099008470727731, 1.823720900329956, None, 4.533191310357748, 4.722350482080537, 2.3535660696411598], [0.7337010652082465, 2.541969317726113, 2.9445193432141497, 2.659788308141465, 1.9433444711249974, 2.874841460209831, None, 2.7989287510239587, 0.3527873988149921], [2.0447320448881765, 4.035236454279488, 2.3292770481337826, 2.39462672758165, 4.956676380797784, 0.17341329726577426, 3.9019605411130787, None, 0.1575277616047449], [3.006371872555087, 1.1541243991539485, 2.4093216069289793, 4.960261365986484, 4.077037968354511, 4.923505978683236, 2.9180448406384816, 4.652223698966106, None]]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/13e791858c7a4b8099b7f44eec14660a-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/13e791858c7a4b8099b7f44eec14660a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 88 COLUMNS
# At line 676 RHS
# At line 760 BOUNDS
# At line 850 ENDATA
# Problem MODEL has 83 rows, 89 columns and 337 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 5.1459 - 0.00 seconds
# Cgl0002I 9 variables fixed
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 74 rows, 80 columns (80 integer (72 of which binary)) and 312 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 1.24345e-14
# Cbc0038I Solution found of 5.1459
# Cbc0038I Cleaned solution of 5.1459
# Cbc0038I Before mini branch and bound, 80 integers at bound fixed and 0 continuous of which 7 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 5.1459 - took 0.00 seconds
# Cbc0012I Integer solution of 5.1459018 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 5.145901809224, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 5.1459 to 5.1459
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.14590181
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/938c6830ef344a4db895a33ec5bd53fd-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/938c6830ef344a4db895a33ec5bd53fd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 88 COLUMNS
# At line 676 RHS
# At line 760 BOUNDS
# At line 850 ENDATA
# Problem MODEL has 83 rows, 89 columns and 337 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.69717 - 0.00 seconds
# Cgl0002I 9 variables fixed
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 74 rows, 80 columns (80 integer (72 of which binary)) and 312 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 8.88178e-15
# Cbc0038I Solution found of 6.69717
# Cbc0038I Cleaned solution of 6.69717
# Cbc0038I Before mini branch and bound, 80 integers at bound fixed and 0 continuous of which 6 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 6.69717 - took 0.00 seconds
# Cbc0012I Integer solution of 6.6971692 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 6.697169196249901, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6.69717 to 6.69717
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.69716920
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/96718d03d00e4f5b81efee0e1d7345d5-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/96718d03d00e4f5b81efee0e1d7345d5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 88 COLUMNS
# At line 676 RHS
# At line 760 BOUNDS
# At line 850 ENDATA
# Problem MODEL has 83 rows, 89 columns and 337 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.06137 - 0.00 seconds
# Cgl0002I 9 variables fixed
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 74 rows, 80 columns (80 integer (72 of which binary)) and 312 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 4.88498e-15
# Cbc0038I Solution found of 9.06137
# Cbc0038I Cleaned solution of 9.06137
# Cbc0038I Before mini branch and bound, 80 integers at bound fixed and 0 continuous of which 5 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 9.06137 - took 0.00 seconds
# Cbc0012I Integer solution of 9.0613687 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 9.0613687116787, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 9.06137 to 9.06137
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                9.06136871
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# (5.267557493449292, [[0, 2, 4, 7, 5, 3, 8, 1, 6]])
# Your code returned tours: [[0, 2, 4, 7, 5, 3, 8, 1, 6]]
# Tour cost obtained by your code: 5.145901809223711
# ------
# test passed: 4 points

# %% [markdown]
# ## Problem 2 (10 points)
#
# We noted the use of Christofides algorithm for metric TSP. We noted that for non-metric TSPs it does not work.
# In fact, the shortcutting used in Christofides algorithm can be _arbitrarily_ bad for a TSP that is symmetric but fails to be a metric TSP.
#
# In this example, we would like you to frame a symmetric TSP instance ($C_{ij} = C_{ji}$) with $5$ vertices wherein the algorithm obtained by "shortcutting" the minimum spanning tree (MST), that would be a 2-factor approximation for metric TSP, yields an answer that can be quite "far off" from the optimal solution.
#
# Enter a __symmetric__ cost-matrix for the TSP below as a 5x5 matrix as a list of lists following convention in our notes. such that the optimal answer is at least $10^6$ times smaller than that obtained by the TSP-based approximation. We will test your answer by running the TSP with shortcutting algorithm.
#
# __Hint:__ Force the edges $(0,1), (1,2), (2,3)$ and $(3,4)$ to be the minimum spanning tree. But make the weight of the edge form $4$ back to $0$ very high.
#
#
# __Note:__ this problem is tricky and requires you to be very familiar with how Christofides algorithm works. It may be wise to attempt the remaining problems first before this one. Do not worry about the diagonal entry of your matrices.

# %%
# Write down the cost matrix as a list of lists. Remember, we want an example with $5$ vertices
# cost_matrix = [[..], [...],[...]]
# The cost matrix should represent a TSP instance such that the optimal answer is 10^6 smaller than the 
# answer obtained by shortcutting a minimum spanning tree.
# your code here
cost_matrix = [[None, 1, 2, 2, int(1e9)],
               [1, None, 1, 2, 2],
               [2, 1, None, 1, 2],
               [2, 2, 1, None, 1],
               [int(1e9), 2, 2, 1, None]]

# %%
# check that the cost matrix is symmetric.
assert len(cost_matrix) == 5, f'Cost matrix must have 5 rows. Yours has {len(cost_matrix)} rows'
assert all(len(cj) == 5 for cj in cost_matrix), f'Each row of the cost matrix must have 5 entries.'
for i in range(5):
    for j in range(i):
        assert cost_matrix[i][j] == cost_matrix[j][i], f'Cost matrix fails to be symmetric at entries {(i,j)} and {(j,i)}'
print('Structure of your cost matrix looks OK (3 points).')
# Out:
# Structure of your cost matrix looks OK (3 points).

# %% [markdown]
# Please ensure that you run the two cells below or else, your tests will fail.

# %%
# MST based tsp approximation
import networkx as nx

# This code implements the simple MST based shortcutting approach that would yield factor of 2
# approximation for metric TSPs.
def minimum_spanning_tree_tsp(n, cost_matrix):
    G = nx.Graph()
    for i in range(n):
        for j in range(i):
            G.add_edge(i, j, weight=cost_matrix[i][j])
    T = nx.minimum_spanning_tree(G)
    print(f'MST for your graph has the edges {T.edges}')
    mst_cost = 0
    mst_dict = {} # store mst as a dictionary
    for (i,j) in T.edges:
        mst_cost += cost_matrix[i][j]
        if i in mst_dict:
            mst_dict[i].append(j)
        else:
            mst_dict[i] = [j]
        if j in mst_dict:
            mst_dict[j].append(i)
        else:
            mst_dict[j] = [i]
    print(f'MST cost: {mst_cost}')
    print(mst_dict)
    # Let's form a tour with short cutting
    def traverse_mst(tour_so_far, cur_node):
        assert cur_node in mst_dict
        next_nodes = mst_dict[cur_node]
        for j in next_nodes:
            if j in tour_so_far:
                continue
            tour_so_far.append(j)
            traverse_mst(tour_so_far, j)
        return
    tour = [0]
    traverse_mst(tour, 0)
    i = 0
    tour_cost = 0
    for j in tour[1:]:
        tour_cost += cost_matrix[i][j]
        i = j
    tour_cost += cost_matrix[i][0]
    return tour, tour_cost

# %%
# optimal TSP tour taken from our notes using MTZ encoding
from pulp import *

def mtz_encoding_tsp(n, cost_matrix):
    assert len(cost_matrix) == n, f'Cost matrix is not {n}x{n}'
    assert all(len(cj) == n for cj in cost_matrix), f'Cost matrix is not {n}x{n}'
    # create our encoding variables
    binary_vars = [ # add a binary variable x_{ij} if i not = j else simply add None
        [ LpVariable(f'x_{i}_{j}', cat='Binary') if i != j else None for j in range(n)] 
        for i in range(n) ]
    # add time stamps for ranges 1 .. n (skip vertex 0 for timestamps)
    time_stamps = [LpVariable(f't_{j}', lowBound=0, upBound=n, cat='Continuous') for j in range(1, n)]
    # create the problem
    prob = LpProblem('TSP-MTZ', LpMinimize)
    # create add the objective function 
    objective_function = lpSum( [ lpSum([xij*cj if xij != None else 0 for (xij, cj) in zip(brow, crow) ])
                           for (brow, crow) in zip(binary_vars, cost_matrix)] )
    
    prob += objective_function 
    
    # add the degree constraints
    for i in range(n):
        # Exactly one leaving variable
        prob += lpSum([xj for xj in binary_vars[i] if xj != None]) == 1
        # Exactly one entering
        prob += lpSum([binary_vars[j][i] for j in range(n) if j != i]) == 1
    # add time stamp constraints
    for i in range(1,n):
        for j in range(1, n):
            if i == j: 
                continue
            xij = binary_vars[i][j]
            ti = time_stamps[i-1]
            tj = time_stamps[j -1]
            prob += tj >= ti + xij - (1-xij)*(n+1) # add the constraint
    # Done: solve the problem
    status = prob.solve(PULP_CBC_CMD(msg=False)) # turn off messages
    assert status == constants.LpStatusOptimal, f'Unexpected non-optimal status {status}'
    # Extract the tour
    tour = [0]
    tour_cost = 0
    while len(tour) < n:
        i = tour[-1]
        # find all indices j such that x_ij >= 0.999 
        sols = [j for (j, xij) in enumerate(binary_vars[i]) if xij != None and xij.varValue >= 0.999]
        assert len(sols) == 1, f'{sols}' # there better be just one such vertex or something has gone quite wrong
        j = sols[0] # extract the lone solutio 
        tour_cost = tour_cost + cost_matrix[i][j] # add to the tour cost
        tour.append(j) # append to the tour
        assert j != 0
    i = tour[-1]
    tour_cost = tour_cost + cost_matrix[i][0]
    return tour, tour_cost

# %%
#test that exact answer is 10^6 times smaller than approximate answer.
# compute MST based approximation
tour, tour_cost = minimum_spanning_tree_tsp(5, cost_matrix)
print(f'MST approximation yields tour is {tour} with cost {tour_cost}')
# compute exact answer
opt_tour, opt_tour_cost = mtz_encoding_tsp(5, cost_matrix)
print(f'Optimal tour is {opt_tour} with cost {opt_tour_cost}')
# check that the fraction is 1million times apart.
assert tour_cost/opt_tour_cost >= 1E+06, 'The TSP + shortcutting tour must be at least 10^6 times costlier than optimum. In your case, the ratio is {tour_cost/opt_tour_cost}'
print('Test passed: 7 points')
# Out:
# MST for your graph has the edges [(1, 0), (1, 2), (2, 3), (3, 4)]
# MST cost: 4
# {1: [0, 2], 0: [1], 2: [1, 3], 3: [2, 4], 4: [3]}
# MST approximation yields tour is [0, 1, 2, 3, 4] with cost 1000000004
# Optimal tour is [0, 2, 3, 4, 1] with cost 7
# Test passed: 7 points

# %% [markdown]
# ## Problem 3
#
# In this problem, we wish to solve TSP with additional constraints. Suppose we are given a TSP instance in the form of a $n\times n$ matrix $C$ representing a complete graph.
#
# We wish to solve a TSP but with additional constraints specified as a list $[(i_0, j_0), \ldots, (i_k, j_k)]$ wherein each pair $(i_l, j_l)$ in the list specifies that vertex $i_l$ must be visited in the tour before vertex $j_l$. Assume that the tour starts/ends at vertex $0$ and none of the vertices in the constraint list is $0$. I.e, $i_l\not= 0, j_l \not= 0$ for all $0 \leq l \leq k$.
#
# Modify one of the ILP encodings we have presented to solve TSP with extra constraints. Implement your solution in the function `tsp_with_extra_constraints(n, cost_matrix, constr_list)` where the extra argument `constr_list` is a list of pairs `[(i0,j0),...., (ik, jk)]` that specify for each pair `(il,jl)` that vertex `il` must be visited before `jl`. Assume that the problem is feasible (no need to handle infeasible instances).
# Your code should output the optimal tour as a list.
#
# ## Example
#
# Consider again the graph with $5$ nodes and the following cost matrix from problem 1:
#
# $$ \begin{array}{c|ccccc}
#   \text{Vertices} & 0 & 1 & 2 & 3 & 4 \\
#    \hline
#  0 & - & 3 & 4 & 3 & 5 \\
#  1 & 1 & - & 2 & 4 & 1 \\
#  2 & 2 & 1 & - & 5 & 4 \\
#  3 & 1 & 1 & 5 & - & 4 \\
#  4 & 2 & 1 & 3 & 5 & - \\
#  \end{array}$$
#
# The optimal TSP tour will be $[0, 3, 1, 4, 2]$ with total cost $10$.
#
# Suppose we added the constraints $[(4, 3), (1, 2)]$ we note that the tour satisfies the constraint $(1, 2)$ since it visits vertex $1$ before vertex $2$ but it unfortunately, $(4,3)$ is violated since vetex $3$ is visited before $4$ in the tour.

# %%
from pulp import *
def tsp_with_extra_constraints(n, cost_matrix, constraints):
    assert len(cost_matrix) == n, f'Cost matrix is not {n}x{n}'
    assert all(len(cj) == n for cj in cost_matrix), f'Cost matrix is not {n}x{n}'
    assert all( 1 <= i < n and 1 <= j < n and i != j for (i,j) in constraints)
    # TODO: encode the problem in pulp (a) decision variables; (b) constraints; (c) objective; (d) solve and extract
    #       solution. This is going to be very close to the MTZ encoding that we have presented in our notes. You can use
    #       our code as a starting point.
    # your code here
    
    prob = LpProblem('TSP', LpMinimize)

    dVars = [[[LpVariable(f'x{i}_{j}', lowBound=0, upBound=1, cat="Integer") for j in range(n)] for i in  range(n)],[LpVariable(f't{i}', lowBound=0, cat="Integer") for i in range(n)]]

    # Objective function
    prob += lpSum([cost_matrix[i][j] * dVars[0][i][j] if i!=j else None for i in range(n) for j in range(n)])

    # Constraints
    for i in range(n):
        prob += lpSum([dVars[0][i][j] for j in range(n)]) == 1
        prob += lpSum([dVars[0][j][i] for j in range(n)]) == 1

    for i in range(n):
        for j in range(n):
            if i!=j and i!=0 and j!=0:
                prob += dVars[1][i] - dVars[1][j] + dVars[0][i][j] - (n - 1) * (1 - dVars[0][i][j]) <= 0
            elif i == j:
                prob += dVars[0][i][j] == 0

    for i,j in constraints:
        prob += dVars[1][j] - dVars[1][i] >= 1

    prob.solve()

    vertices = [i for i in range(n)]
    j = 0
    tour = [0]
    while len(vertices) > 0:
        for l in vertices:
            if dVars[0][j][l].varValue == 1:
                if l!=0: tour.append(l)
                vertices.remove(l)
                j = l
                break
        if j == 0:
            break
    return tour
    raise NotImplementedError

# %%
cost_matrix=[ [None,3,4,3,5],
             [1, None, 2,4, 1],
             [2, 1, None, 5, 4],
             [1, 1, 5, None, 4],
             [2, 1, 3, 5, None] ]
n=5
constraints = [(3,4),(1,2)]
tour = tsp_with_extra_constraints(n, cost_matrix, constraints)
i = 0
tour_cost = 0
for j in tour[1:]:
    tour_cost += cost_matrix[i][j]
    i = j
tour_cost += cost_matrix[i][0]
print(f'Tour:{tour}')
print(f'Cost of your tour: {tour_cost}')
assert abs(tour_cost-10) <= 0.001, 'Expected cost was 10'
for i in range(n):
    num = sum([1 if j == i else 0 for j in tour])
    assert  num == 1, f'Vertex {i} repeats {num} times in tour'
for (i, j) in constraints:
    assert tour.index(i) < tour.index(j), f'Tour does not respect constraint {(i,j)}'
print('Test Passed (3 points)')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/f719483ac1b44a6293fbc393f161440a-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/f719483ac1b44a6293fbc393f161440a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 34 COLUMNS
# At line 208 RHS
# At line 238 BOUNDS
# At line 268 ENDATA
# Problem MODEL has 29 rows, 29 columns and 95 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.5 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 24 rows, 24 columns (24 integer (20 of which binary)) and 80 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 11 integers unsatisfied sum - 2.8
# Cbc0038I Pass   1: suminf.    2.80000 (11) obj. 10.4 iterations 2
# Cbc0038I Pass   2: suminf.    2.40000 (6) obj. 14.6 iterations 8
# Cbc0038I Pass   3: suminf.    1.60000 (4) obj. 15 iterations 5
# Cbc0038I Pass   4: suminf.    1.60000 (4) obj. 14.2 iterations 6
# Cbc0038I Pass   5: suminf.    2.80000 (8) obj. 13.6 iterations 4
# Cbc0038I Pass   6: suminf.    1.60000 (4) obj. 14.8 iterations 2
# Cbc0038I Pass   7: suminf.    1.60000 (4) obj. 16.8 iterations 6
# Cbc0038I Pass   8: suminf.    0.00000 (0) obj. 18 iterations 6
# Cbc0038I Solution found of 18
# Cbc0038I Cleaned solution of 18
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 24 rows 24 columns, reduced to 24 rows 21 columns
# Cbc0038I Mini branch and bound improved solution from 18 to 10 (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 10 - took 0.00 seconds
# Cbc0012I Integer solution of 10 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 10, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 10 variables fixed on reduced cost
# Cuts at root node changed objective from 9.5 to 9.5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                10.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Tour:[0, 3, 1, 4, 2]
# Cost of your tour: 10
# Test Passed (3 points)

# %%
cost_matrix=[ [None,3,4,3,5],
             [1, None, 2,4, 1],
             [2, 1, None, 5, 4],
             [1, 1, 5, None, 4],
             [2, 1, 3, 5, None] ]
n=5
constraints = [(4,3),(1,2)]
tour = tsp_with_extra_constraints(n, cost_matrix, constraints)
i = 0
tour_cost = 0
for j in tour[1:]:
    tour_cost += cost_matrix[i][j]
    i = j
tour_cost += cost_matrix[i][0]
print(f'Tour:{tour}')
print(f'Cost of your tour: {tour_cost}')
assert abs(tour_cost-13) <= 0.001, 'Expected cost was 13'
for i in range(n):
    num = sum([1 if j == i else 0 for j in tour])
    assert  num == 1, f'Vertex {i} repeats {num} times in tour'
for (i, j) in constraints:
    assert tour.index(i) < tour.index(j), f'Tour does not respect constraint {(i,j)}'
print('Test Passed (3 points)')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/54e73994a7f3457caffbe88179a7bf74-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/54e73994a7f3457caffbe88179a7bf74-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 34 COLUMNS
# At line 208 RHS
# At line 238 BOUNDS
# At line 268 ENDATA
# Problem MODEL has 29 rows, 29 columns and 95 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.5 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 24 rows, 24 columns (24 integer (20 of which binary)) and 80 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 11 integers unsatisfied sum - 2.8
# Cbc0038I Pass   1: suminf.    2.80000 (11) obj. 10.4 iterations 2
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 15 iterations 11
# Cbc0038I Solution found of 15
# Cbc0038I Cleaned solution of 15
# Cbc0038I Before mini branch and bound, 9 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 24 rows 24 columns, reduced to 6 rows 3 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of 13.5501
# Cbc0038I Pass   3: suminf.    2.80000 (11) obj. 10.4 iterations 0
# Cbc0038I Pass   4: suminf.    0.85003 (5) obj. 13.5501 iterations 11
# Cbc0038I Pass   5: suminf.    0.85003 (5) obj. 13.5501 iterations 3
# Cbc0038I Pass   6: suminf.    2.80000 (8) obj. 10.4 iterations 10
# Cbc0038I Pass   7: suminf.    2.80000 (8) obj. 11.3 iterations 4
# Cbc0038I Pass   8: suminf.    2.80000 (8) obj. 10.4 iterations 3
# Cbc0038I Pass   9: suminf.    2.80000 (11) obj. 10.4 iterations 6
# Cbc0038I Pass  10: suminf.    0.85003 (5) obj. 13.5501 iterations 11
# Cbc0038I Pass  11: suminf.    0.85003 (5) obj. 13.5501 iterations 3
# Cbc0038I Pass  12: suminf.    1.71986 (11) obj. 13.5501 iterations 2
# Cbc0038I Pass  13: suminf.    0.85003 (5) obj. 13.5501 iterations 2
# Cbc0038I Pass  14: suminf.    2.80000 (8) obj. 10.4 iterations 10
# Cbc0038I Pass  15: suminf.    2.80000 (11) obj. 10.4 iterations 6
# Cbc0038I Pass  16: suminf.    0.85003 (5) obj. 13.5501 iterations 11
# Cbc0038I Pass  17: suminf.    0.85003 (5) obj. 13.5501 iterations 2
# Cbc0038I Pass  18: suminf.    1.71986 (11) obj. 13.5501 iterations 2
# Cbc0038I Pass  19: suminf.    2.20036 (8) obj. 13.5501 iterations 8
# Cbc0038I Pass  20: suminf.    0.00000 (0) obj. 13 iterations 11
# Cbc0038I Solution found of 13
# Cbc0038I Cleaned solution of 13
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 24 rows 24 columns, reduced to 20 rows 15 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 11.5001
# Cbc0038I Pass  21: suminf.    2.80000 (11) obj. 10.4 iterations 0
# Cbc0038I Pass  22: suminf.    3.35004 (11) obj. 11.5001 iterations 3
# Cbc0038I Pass  23: suminf.    2.80000 (8) obj. 10.4 iterations 3
# Cbc0038I Pass  24: suminf.    2.80000 (8) obj. 10.4 iterations 0
# Cbc0038I Pass  25: suminf.    2.45012 (11) obj. 11.5001 iterations 2
# Cbc0038I Pass  26: suminf.    2.80000 (8) obj. 10.4 iterations 3
# Cbc0038I Pass  27: suminf.    3.19888 (9) obj. 11.5001 iterations 5
# Cbc0038I Pass  28: suminf.    2.29944 (11) obj. 11.5001 iterations 3
# Cbc0038I Pass  29: suminf.    2.29944 (11) obj. 11.5001 iterations 0
# Cbc0038I Pass  30: suminf.    2.40000 (6) obj. 9.8 iterations 7
# Cbc0038I Pass  31: suminf.    2.80000 (11) obj. 10.4 iterations 3
# Cbc0038I Pass  32: suminf.    3.35004 (11) obj. 11.5001 iterations 3
# Cbc0038I Pass  33: suminf.    2.80000 (8) obj. 10.4 iterations 3
# Cbc0038I Pass  34: suminf.    2.56013 (11) obj. 11.5001 iterations 2
# Cbc0038I Pass  35: suminf.    2.80000 (8) obj. 10.4 iterations 2
# Cbc0038I Pass  36: suminf.    2.80000 (11) obj. 11.5001 iterations 1
# Cbc0038I Pass  37: suminf.    3.33344 (9) obj. 11.5001 iterations 5
# Cbc0038I Pass  38: suminf.    2.59984 (10) obj. 11.5001 iterations 4
# Cbc0038I Pass  39: suminf.    2.59984 (9) obj. 11.5001 iterations 1
# Cbc0038I Pass  40: suminf.    2.40000 (6) obj. 9.8 iterations 3
# Cbc0038I Pass  41: suminf.    2.80000 (11) obj. 10.4 iterations 3
# Cbc0038I Pass  42: suminf.    3.35004 (11) obj. 11.5001 iterations 3
# Cbc0038I Pass  43: suminf.    2.80000 (8) obj. 10.4 iterations 3
# Cbc0038I Pass  44: suminf.    3.40000 (13) obj. 11.5001 iterations 3
# Cbc0038I Pass  45: suminf.    2.80000 (8) obj. 10.4 iterations 3
# Cbc0038I Pass  46: suminf.    2.14956 (11) obj. 11.5001 iterations 4
# Cbc0038I Pass  47: suminf.    2.29944 (11) obj. 11.5001 iterations 2
# Cbc0038I Pass  48: suminf.    2.40000 (6) obj. 9.8 iterations 7
# Cbc0038I Pass  49: suminf.    2.80000 (11) obj. 10.4 iterations 3
# Cbc0038I Pass  50: suminf.    3.35004 (11) obj. 11.5001 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 24 rows 24 columns, reduced to 24 rows 22 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 13 - took 0.02 seconds
# Cbc0012I Integer solution of 13 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0031I 2 added rows had average density of 4.5
# Cbc0013I At root node, 19 cuts changed objective from 9.5 to 12.48 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 7 column cuts (7 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 18 row cuts average 6.8 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 56 row cuts average 6.1 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 11 row cuts average 6.1 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 13, took 17 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 9.5 to 12.48
# Probing was tried 4 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 4 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 4 times and created 56 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 4 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
#
# Result - Optimal solution found
#
# Objective value:                13.00000000
# Enumerated nodes:               0
# Total iterations:               17
# Time (CPU seconds):             0.04
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.06
#
# Tour:[0, 1, 4, 2, 3]
# Cost of your tour: 13
# Test Passed (3 points)

# %%
from random import uniform, randint

def create_cost(n):
    return [ [uniform(0, 5) if i != j else None for j in range(n)] for i in range(n)]

for trial in range(20):
    print(f'Trial # {trial}')
    n = randint(6, 11)
    cost_matrix = create_cost(n)
    constraints = [(1, 3), (4, 2), (n-1, 1), (n-2, 2)]
    tour = tsp_with_extra_constraints(n, cost_matrix, constraints)
    i = 0
    tour_cost = 0
    for j in tour[1:]:
        tour_cost += cost_matrix[i][j]
        i = j
    tour_cost += cost_matrix[i][0]
    print(f'Tour:{tour}')
    print(f'Cost of your tour: {tour_cost}')
    for i in range(n):
        num = sum([1 if j == i else 0 for j in tour])
        assert  num == 1, f'Vertex {i} repeats {num} times in tour'
    for (i, j) in constraints:
        assert tour.index(i) < tour.index(j), f'Tour does not respect constraint {(i,j)}'
print('Test Passed (10 points)')
# Out:
# Trial # 0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/10488fd54f0447d99fd1b4ca77d91745-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/10488fd54f0447d99fd1b4ca77d91745-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 47 COLUMNS
# At line 306 RHS
# At line 349 BOUNDS
# At line 391 ENDATA
# Problem MODEL has 42 rows, 41 columns and 146 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.35434 - 0.00 seconds
# Cgl0002I 6 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 35 rows, 35 columns (35 integer (30 of which binary)) and 126 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 2
# Cbc0038I Pass   1: suminf.    2.00000 (4) obj. 9.35434 iterations 3
# Cbc0038I Pass   2: suminf.    2.66667 (6) obj. 9.38797 iterations 3
# Cbc0038I Pass   3: suminf.    2.66667 (6) obj. 9.38797 iterations 1
# Cbc0038I Pass   4: suminf.    2.00000 (4) obj. 9.35434 iterations 3
# Cbc0038I Pass   5: suminf.    2.66667 (9) obj. 21.4089 iterations 16
# Cbc0038I Pass   6: suminf.    2.55556 (9) obj. 21.3538 iterations 8
# Cbc0038I Pass   7: suminf.    2.00000 (10) obj. 21.8009 iterations 5
# Cbc0038I Pass   8: suminf.    2.50000 (8) obj. 21.9983 iterations 14
# Cbc0038I Pass   9: suminf.    2.00000 (4) obj. 21.4186 iterations 3
# Cbc0038I Pass  10: suminf.    2.00000 (4) obj. 21.4186 iterations 0
# Cbc0038I Pass  11: suminf.    2.00000 (4) obj. 21.4186 iterations 6
# Cbc0038I Pass  12: suminf.    2.33333 (8) obj. 21.3849 iterations 10
# Cbc0038I Pass  13: suminf.    2.00000 (7) obj. 22.7694 iterations 5
# Cbc0038I Pass  14: suminf.    1.33333 (4) obj. 21.1316 iterations 12
# Cbc0038I Pass  15: suminf.    2.00000 (4) obj. 20.9108 iterations 4
# Cbc0038I Pass  16: suminf.    2.00000 (4) obj. 20.9108 iterations 0
# Cbc0038I Pass  17: suminf.    1.33333 (4) obj. 21.1316 iterations 7
# Cbc0038I Pass  18: suminf.    2.00000 (4) obj. 15.246 iterations 10
# Cbc0038I Pass  19: suminf.    2.00000 (4) obj. 15.246 iterations 2
# Cbc0038I Pass  20: suminf.    2.00000 (4) obj. 15.246 iterations 3
# Cbc0038I Pass  21: suminf.    2.00000 (4) obj. 19.1977 iterations 9
# Cbc0038I Pass  22: suminf.    2.00000 (7) obj. 17.6768 iterations 3
# Cbc0038I Pass  23: suminf.    1.33333 (4) obj. 19.2794 iterations 12
# Cbc0038I Pass  24: suminf.    2.00000 (4) obj. 19.0586 iterations 8
# Cbc0038I Pass  25: suminf.    2.00000 (4) obj. 19.0586 iterations 4
# Cbc0038I Pass  26: suminf.    1.33333 (4) obj. 19.2794 iterations 4
# Cbc0038I Pass  27: suminf.    1.33333 (4) obj. 19.2794 iterations 6
# Cbc0038I Pass  28: suminf.    4.00000 (8) obj. 14.6265 iterations 15
# Cbc0038I Pass  29: suminf.    4.00000 (8) obj. 16.4322 iterations 9
# Cbc0038I Pass  30: suminf.    2.00000 (4) obj. 16.8162 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 35 rows 35 columns, reduced to 35 rows 31 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to 18.9999 (0.01 seconds)
# Cbc0038I Round again with cutoff of 18.0353
# Cbc0038I Pass  30: suminf.    2.00000 (4) obj. 9.35434 iterations 0
# Cbc0038I Pass  31: suminf.    2.66667 (6) obj. 9.38797 iterations 2
# Cbc0038I Pass  32: suminf.    2.00000 (4) obj. 9.35434 iterations 3
# Cbc0038I Pass  33: suminf.    2.00000 (4) obj. 9.35434 iterations 2
# Cbc0038I Pass  34: suminf.    2.00000 (6) obj. 14.4286 iterations 11
# Cbc0038I Pass  35: suminf.    1.33333 (4) obj. 13.0458 iterations 5
# Cbc0038I Pass  36: suminf.    1.33333 (4) obj. 14.2496 iterations 8
# Cbc0038I Pass  37: suminf.    2.89824 (12) obj. 18.0353 iterations 7
# Cbc0038I Pass  38: suminf.    2.62806 (12) obj. 18.0353 iterations 11
# Cbc0038I Pass  39: suminf.    2.62806 (12) obj. 18.0353 iterations 1
# Cbc0038I Pass  40: suminf.    2.66667 (7) obj. 12.1983 iterations 17
# Cbc0038I Pass  41: suminf.    2.33333 (7) obj. 12.6465 iterations 1
# Cbc0038I Pass  42: suminf.    2.33333 (9) obj. 13.0336 iterations 11
# Cbc0038I Pass  43: suminf.    2.33333 (9) obj. 13.0336 iterations 1
# Cbc0038I Pass  44: suminf.    3.00000 (6) obj. 13.922 iterations 6
# Cbc0038I Pass  45: suminf.    2.66667 (6) obj. 11.2532 iterations 4
# Cbc0038I Pass  46: suminf.    2.00000 (4) obj. 11.2196 iterations 4
# Cbc0038I Pass  47: suminf.    3.33638 (11) obj. 18.0353 iterations 16
# Cbc0038I Pass  48: suminf.    2.99627 (12) obj. 18.0353 iterations 8
# Cbc0038I Pass  49: suminf.    2.00000 (9) obj. 17.3709 iterations 1
# Cbc0038I Pass  50: suminf.    3.05848 (11) obj. 18.0353 iterations 14
# Cbc0038I Pass  51: suminf.    2.57112 (8) obj. 18.0353 iterations 8
# Cbc0038I Pass  52: suminf.    2.00000 (4) obj. 16.198 iterations 4
# Cbc0038I Pass  53: suminf.    2.66667 (6) obj. 16.2316 iterations 6
# Cbc0038I Pass  54: suminf.    2.00000 (4) obj. 16.198 iterations 5
# Cbc0038I Pass  55: suminf.    4.00000 (8) obj. 17.0852 iterations 6
# Cbc0038I Pass  56: suminf.    1.33333 (4) obj. 16.9704 iterations 10
# Cbc0038I Pass  57: suminf.    1.33333 (4) obj. 16.9704 iterations 0
# Cbc0038I Pass  58: suminf.    1.33333 (4) obj. 15.7665 iterations 4
# Cbc0038I Pass  59: suminf.    1.33333 (4) obj. 17.6169 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 35 rows 35 columns, reduced to 34 rows 30 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 18.9999 - took 0.02 seconds
# Cbc0012I Integer solution of 18.999858 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0031I 6 added rows had average density of 14.5
# Cbc0013I At root node, 6 cuts changed objective from 9.3543416 to 16.090668 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 491 row cuts average 23.2 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 23 row cuts average 11.5 elements, 0 column cuts (0 active)  in 0.025 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 59 row cuts average 19.7 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 162 row cuts average 7.3 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 18.999858 best solution, best possible 16.090668 (0.11 seconds)
# Cbc0012I Integer solution of 18.448295 found by DiveCoefficient after 1553 iterations and 1 nodes (0.12 seconds)
# Cbc0001I Search completed - best objective 18.4482948731653, took 1579 iterations and 4 nodes (0.12 seconds)
# Cbc0032I Strong branching done 48 times (292 iterations), fathomed 0 nodes and fixed 1 variables
# Cbc0035I Maximum depth 1, 7 variables fixed on reduced cost
# Cuts at root node changed objective from 9.35434 to 16.0907
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Gomory was tried 113 times and created 598 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# Knapsack was tried 113 times and created 27 cuts of which 0 were active after adding rounds of cuts (0.026 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 113 times and created 71 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# TwoMirCuts was tried 113 times and created 284 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 13 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                18.44829487
# Enumerated nodes:               4
# Total iterations:               1579
# Time (CPU seconds):             0.11
# Time (Wallclock seconds):       0.12
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.11   (Wallclock seconds):       0.12
#
# Tour:[0, 5, 1, 3, 4, 2]
# Cost of your tour: 18.448294873164645
# Trial # 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/6df75f0dacf64881a731f89e98a0e16b-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/6df75f0dacf64881a731f89e98a0e16b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 47 COLUMNS
# At line 306 RHS
# At line 349 BOUNDS
# At line 391 ENDATA
# Problem MODEL has 42 rows, 41 columns and 146 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.97911 - 0.00 seconds
# Cgl0002I 6 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 35 rows, 35 columns (35 integer (30 of which binary)) and 126 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.33333
# Cbc0038I Pass   1: suminf.    1.33333 (4) obj. 9.97911 iterations 3
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 10.034 iterations 7
# Cbc0038I Solution found of 10.034
# Cbc0038I Cleaned solution of 10.034
# Cbc0038I Before mini branch and bound, 28 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 35 rows 35 columns, reduced to 4 rows 3 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of 10.0285
# Cbc0038I Reduced cost fixing fixed 19 variables on major pass 2
# Cbc0038I Pass   3: suminf.    1.33333 (4) obj. 9.97911 iterations 0
# Cbc0038I Pass   4: suminf.    1.46907 (7) obj. 10.0285 iterations 4
# Cbc0038I Pass   5: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass   6: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass   7: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass   8: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass   9: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass  10: suminf.    1.33333 (4) obj. 9.97911 iterations 2
# Cbc0038I Pass  11: suminf.    1.33333 (4) obj. 9.97911 iterations 0
# Cbc0038I Pass  12: suminf.    1.46907 (7) obj. 10.0285 iterations 2
# Cbc0038I Pass  13: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass  14: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass  15: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass  16: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass  17: suminf.    1.33333 (4) obj. 9.97911 iterations 2
# Cbc0038I Pass  18: suminf.    1.33333 (4) obj. 9.97911 iterations 0
# Cbc0038I Pass  19: suminf.    1.46907 (7) obj. 10.0285 iterations 2
# Cbc0038I Pass  20: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass  21: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass  22: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass  23: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass  24: suminf.    1.33333 (4) obj. 9.97911 iterations 2
# Cbc0038I Pass  25: suminf.    1.33333 (4) obj. 9.97911 iterations 0
# Cbc0038I Pass  26: suminf.    1.33333 (4) obj. 9.97911 iterations 0
# Cbc0038I Pass  27: suminf.    1.46907 (7) obj. 10.0285 iterations 2
# Cbc0038I Pass  28: suminf.    1.33333 (4) obj. 9.97911 iterations 2
# Cbc0038I Pass  29: suminf.    1.33333 (4) obj. 9.97911 iterations 0
# Cbc0038I Pass  30: suminf.    1.46907 (7) obj. 10.0285 iterations 2
# Cbc0038I Pass  31: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I Pass  32: suminf.    1.46907 (7) obj. 10.0285 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 28 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 10.034 - took 0.00 seconds
# Cbc0012I Integer solution of 10.033978 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 9.9791095 to 9.9791095 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 2 column cuts (2 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 10.0339783378315, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 19 variables fixed on reduced cost
# Cuts at root node changed objective from 9.97911 to 9.97911
# Probing was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                10.03397834
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Tour:[0, 4, 2, 5, 1, 3]
# Cost of your tour: 10.033978337831048
# Trial # 2
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/753a4b42ee5e4337b319098512f6f49d-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/753a4b42ee5e4337b319098512f6f49d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 47 COLUMNS
# At line 306 RHS
# At line 349 BOUNDS
# At line 391 ENDATA
# Problem MODEL has 42 rows, 41 columns and 146 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.42429 - 0.00 seconds
# Cgl0002I 6 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 35 rows, 35 columns (35 integer (30 of which binary)) and 126 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 2
# Cbc0038I Pass   1: suminf.    2.00000 (4) obj. 7.42429 iterations 6
# Cbc0038I Pass   2: suminf.    2.66667 (6) obj. 7.44628 iterations 5
# Cbc0038I Pass   3: suminf.    2.66667 (6) obj. 7.44628 iterations 1
# Cbc0038I Pass   4: suminf.    2.00000 (4) obj. 7.42429 iterations 5
# Cbc0038I Pass   5: suminf.    2.00000 (4) obj. 7.42429 iterations 0
# Cbc0038I Pass   6: suminf.    2.66667 (6) obj. 7.44628 iterations 8
# Cbc0038I Pass   7: suminf.    4.00000 (11) obj. 9.65365 iterations 9
# Cbc0038I Pass   8: suminf.    2.66667 (7) obj. 9.06908 iterations 6
# Cbc0038I Pass   9: suminf.    1.33333 (4) obj. 10.3454 iterations 11
# Cbc0038I Pass  10: suminf.    1.33333 (4) obj. 10.3454 iterations 2
# Cbc0038I Pass  11: suminf.    2.00000 (4) obj. 11.3891 iterations 7
# Cbc0038I Pass  12: suminf.    2.00000 (7) obj. 14.5347 iterations 11
# Cbc0038I Pass  13: suminf.    1.33333 (4) obj. 14.9809 iterations 11
# Cbc0038I Pass  14: suminf.    2.00000 (4) obj. 14.7031 iterations 5
# Cbc0038I Pass  15: suminf.    2.00000 (4) obj. 14.7031 iterations 2
# Cbc0038I Pass  16: suminf.    1.33333 (4) obj. 14.9809 iterations 4
# Cbc0038I Pass  17: suminf.    2.66667 (8) obj. 15.6321 iterations 17
# Cbc0038I Pass  18: suminf.    1.33333 (4) obj. 16.1868 iterations 23
# Cbc0038I Pass  19: suminf.    3.16667 (11) obj. 15.3926 iterations 9
# Cbc0038I Pass  20: suminf.    3.16667 (11) obj. 15.3926 iterations 0
# Cbc0038I Pass  21: suminf.    3.50000 (8) obj. 11.9405 iterations 12
# Cbc0038I Pass  22: suminf.    2.83333 (9) obj. 11.2867 iterations 7
# Cbc0038I Pass  23: suminf.    1.33333 (4) obj. 13.5956 iterations 13
# Cbc0038I Pass  24: suminf.    1.33333 (4) obj. 13.5956 iterations 2
# Cbc0038I Pass  25: suminf.    2.00000 (6) obj. 13.6067 iterations 6
# Cbc0038I Pass  26: suminf.    2.00000 (7) obj. 11.3842 iterations 10
# Cbc0038I Pass  27: suminf.    2.00000 (7) obj. 11.3842 iterations 0
# Cbc0038I Pass  28: suminf.    3.50000 (8) obj. 11.9405 iterations 9
# Cbc0038I Pass  29: suminf.    2.83333 (9) obj. 11.2867 iterations 6
# Cbc0038I Pass  30: suminf.    1.33333 (4) obj. 13.5956 iterations 12
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 35 rows 35 columns, reduced to 34 rows 27 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting - took 0.01 seconds
# Cbc0012I Integer solution of 11.353134 found by DiveCoefficient after 44 iterations and 0 nodes (0.02 seconds)
# Cbc0031I 7 added rows had average density of 13.142857
# Cbc0013I At root node, 7 cuts changed objective from 7.4242855 to 11.353134 in 7 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 41 row cuts average 16.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 72 row cuts average 13.2 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 11.3531340602214, took 44 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 7.42429 to 11.3531
# Probing was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 7 times and created 41 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 7 times and created 72 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                11.35313406
# Enumerated nodes:               0
# Total iterations:               44
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Tour:[0, 5, 1, 3, 4, 2]
# Cost of your tour: 11.353134060220764
# Trial # 3
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/bc1ce35675c94a4ea2fed1afbd14aef6-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/bc1ce35675c94a4ea2fed1afbd14aef6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 92 COLUMNS
# At line 690 RHS
# At line 778 BOUNDS
# At line 868 ENDATA
# Problem MODEL has 87 rows, 89 columns and 347 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.23939 - 0.00 seconds
# Cgl0002I 9 variables fixed
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 78 rows, 80 columns (80 integer (72 of which binary)) and 320 elements
# Cbc0038I Initial state - 12 integers unsatisfied sum - 3.72222
# Cbc0038I Pass   1: suminf.    1.11111 (7) obj. 8.05864 iterations 24
# Cbc0038I Pass   2: suminf.    2.11111 (9) obj. 11.1273 iterations 10
# Cbc0038I Pass   3: suminf.    1.11111 (7) obj. 11.6969 iterations 11
# Cbc0038I Pass   4: suminf.    1.77778 (4) obj. 11.5501 iterations 21
# Cbc0038I Pass   5: suminf.    1.11111 (7) obj. 13.7024 iterations 12
# Cbc0038I Pass   6: suminf.    2.11111 (9) obj. 11.4971 iterations 23
# Cbc0038I Pass   7: suminf.    3.33333 (10) obj. 20.3526 iterations 32
# Cbc0038I Pass   8: suminf.    1.33333 (7) obj. 20.9125 iterations 21
# Cbc0038I Pass   9: suminf.    2.66667 (8) obj. 20.9335 iterations 14
# Cbc0038I Pass  10: suminf.    2.83333 (14) obj. 21.4605 iterations 8
# Cbc0038I Pass  11: suminf.    1.33333 (6) obj. 25.1998 iterations 27
# Cbc0038I Pass  12: suminf.    1.33333 (4) obj. 26.509 iterations 14
# Cbc0038I Pass  13: suminf.    1.33333 (4) obj. 26.498 iterations 14
# Cbc0038I Pass  14: suminf.    2.83333 (10) obj. 24.6555 iterations 14
# Cbc0038I Pass  15: suminf.    1.33333 (8) obj. 27.4941 iterations 16
# Cbc0038I Pass  16: suminf.    1.33333 (6) obj. 26.9731 iterations 10
# Cbc0038I Pass  17: suminf.    3.11111 (14) obj. 29.6306 iterations 27
# Cbc0038I Pass  18: suminf.    1.33333 (7) obj. 28.1383 iterations 24
# Cbc0038I Pass  19: suminf.    1.33333 (6) obj. 28.4869 iterations 14
# Cbc0038I Pass  20: suminf.    1.33333 (6) obj. 28.4869 iterations 7
# Cbc0038I Pass  21: suminf.    1.33333 (4) obj. 25.9825 iterations 22
# Cbc0038I Pass  22: suminf.    1.77778 (8) obj. 24.393 iterations 24
# Cbc0038I Pass  23: suminf.    1.33333 (6) obj. 25.4076 iterations 18
# Cbc0038I Pass  24: suminf.    1.33333 (6) obj. 26.5112 iterations 23
# Cbc0038I Pass  25: suminf.    1.33333 (7) obj. 22.8344 iterations 28
# Cbc0038I Pass  26: suminf.    1.33333 (6) obj. 25.5264 iterations 14
# Cbc0038I Pass  27: suminf.    1.33333 (6) obj. 25.5264 iterations 5
# Cbc0038I Pass  28: suminf.    1.33333 (6) obj. 24.1789 iterations 12
# Cbc0038I Pass  29: suminf.    3.77778 (13) obj. 18.3801 iterations 15
# Cbc0038I Pass  30: suminf.    1.77778 (12) obj. 15.8017 iterations 16
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 78 rows 80 columns, reduced to 78 rows 61 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to 14.4499 (0.05 seconds)
# Cbc0038I Round again with cutoff of 13.7288
# Cbc0038I Pass  30: suminf.    1.11111 (7) obj. 8.05864 iterations 0
# Cbc0038I Pass  31: suminf.    2.11111 (9) obj. 11.1273 iterations 27
# Cbc0038I Pass  32: suminf.    1.11111 (7) obj. 11.6969 iterations 16
# Cbc0038I Pass  33: suminf.    1.77778 (4) obj. 11.5501 iterations 27
# Cbc0038I Pass  34: suminf.    1.11111 (7) obj. 13.7024 iterations 12
# Cbc0038I Pass  35: suminf.    2.11111 (9) obj. 11.4971 iterations 22
# Cbc0038I Pass  36: suminf.    2.89034 (13) obj. 13.7288 iterations 18
# Cbc0038I Pass  37: suminf.    2.69105 (15) obj. 13.7288 iterations 22
# Cbc0038I Pass  38: suminf.    2.66667 (6) obj. 9.09818 iterations 32
# Cbc0038I Pass  39: suminf.    0.88889 (4) obj. 10.7182 iterations 21
# Cbc0038I Pass  40: suminf.    0.88889 (4) obj. 12.0409 iterations 14
# Cbc0038I Pass  41: suminf.    1.57400 (4) obj. 13.7288 iterations 12
# Cbc0038I Pass  42: suminf.    1.81074 (10) obj. 13.7288 iterations 9
# Cbc0038I Pass  43: suminf.    1.57400 (4) obj. 13.7288 iterations 7
# Cbc0038I Pass  44: suminf.    1.17483 (10) obj. 13.7288 iterations 17
# Cbc0038I Pass  45: suminf.    1.88889 (14) obj. 13.7288 iterations 13
# Cbc0038I Pass  46: suminf.    1.33333 (4) obj. 8.77198 iterations 32
# Cbc0038I Pass  47: suminf.    2.50000 (9) obj. 8.70469 iterations 14
# Cbc0038I Pass  48: suminf.    0.88889 (4) obj. 11.4141 iterations 25
# Cbc0038I Pass  49: suminf.    1.33333 (6) obj. 12.1022 iterations 16
# Cbc0038I Pass  50: suminf.    2.52341 (9) obj. 13.7288 iterations 17
# Cbc0038I Pass  51: suminf.    1.33333 (4) obj. 8.96828 iterations 17
# Cbc0038I Pass  52: suminf.    2.50000 (9) obj. 8.70469 iterations 6
# Cbc0038I Pass  53: suminf.    0.88889 (4) obj. 11.4141 iterations 25
# Cbc0038I Pass  54: suminf.    1.33333 (6) obj. 12.1022 iterations 16
# Cbc0038I Pass  55: suminf.    2.52341 (9) obj. 13.7288 iterations 17
# Cbc0038I Pass  56: suminf.    1.33333 (4) obj. 8.96828 iterations 17
# Cbc0038I Pass  57: suminf.    2.50000 (9) obj. 8.70469 iterations 6
# Cbc0038I Pass  58: suminf.    0.88889 (4) obj. 11.4141 iterations 24
# Cbc0038I Pass  59: suminf.    1.33333 (6) obj. 12.1022 iterations 16
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 78 rows 80 columns, reduced to 73 rows 40 columns
# Cbc0038I Mini branch and bound improved solution from 14.4499 to 11.327 (0.07 seconds)
# Cbc0038I Round again with cutoff of 10.5095
# Cbc0038I Reduced cost fixing fixed 14 variables on major pass 3
# Cbc0038I Pass  59: suminf.    1.11111 (7) obj. 8.05864 iterations 0
# Cbc0038I Pass  60: suminf.    3.04128 (16) obj. 10.5095 iterations 25
# Cbc0038I Pass  61: suminf.    3.04128 (16) obj. 10.5095 iterations 0
# Cbc0038I Pass  62: suminf.    3.61111 (13) obj. 8.39492 iterations 19
# Cbc0038I Pass  63: suminf.    1.77778 (7) obj. 8.95283 iterations 6
# Cbc0038I Pass  64: suminf.    1.11111 (7) obj. 8.05864 iterations 5
# Cbc0038I Pass  65: suminf.    3.04128 (16) obj. 10.5095 iterations 26
# Cbc0038I Pass  66: suminf.    3.04128 (16) obj. 10.5095 iterations 0
# Cbc0038I Pass  67: suminf.    3.61111 (13) obj. 8.39492 iterations 20
# Cbc0038I Pass  68: suminf.    1.77778 (7) obj. 8.95283 iterations 6
# Cbc0038I Pass  69: suminf.    1.11111 (7) obj. 8.05864 iterations 5
# Cbc0038I Pass  70: suminf.    3.04128 (16) obj. 10.5095 iterations 25
# Cbc0038I Pass  71: suminf.    3.04128 (16) obj. 10.5095 iterations 0
# Cbc0038I Pass  72: suminf.    3.61111 (13) obj. 8.39492 iterations 20
# Cbc0038I Pass  73: suminf.    1.77778 (7) obj. 8.95283 iterations 6
# Cbc0038I Pass  74: suminf.    1.11111 (7) obj. 8.05864 iterations 5
# Cbc0038I Pass  75: suminf.    3.04128 (16) obj. 10.5095 iterations 23
# Cbc0038I Pass  76: suminf.    3.04128 (16) obj. 10.5095 iterations 0
# Cbc0038I Pass  77: suminf.    3.61111 (13) obj. 8.39492 iterations 18
# Cbc0038I Pass  78: suminf.    1.77778 (7) obj. 8.95283 iterations 6
# Cbc0038I Pass  79: suminf.    1.11111 (7) obj. 8.05864 iterations 5
# Cbc0038I Pass  80: suminf.    3.04128 (16) obj. 10.5095 iterations 23
# Cbc0038I Pass  81: suminf.    3.04128 (16) obj. 10.5095 iterations 0
# Cbc0038I Pass  82: suminf.    3.61111 (13) obj. 8.39492 iterations 17
# Cbc0038I Pass  83: suminf.    1.77778 (7) obj. 8.95283 iterations 6
# Cbc0038I Pass  84: suminf.    1.11111 (7) obj. 8.05864 iterations 5
# Cbc0038I Pass  85: suminf.    3.04128 (16) obj. 10.5095 iterations 26
# Cbc0038I Pass  86: suminf.    3.04128 (16) obj. 10.5095 iterations 0
# Cbc0038I Pass  87: suminf.    3.61111 (13) obj. 8.39492 iterations 21
# Cbc0038I Pass  88: suminf.    1.77778 (7) obj. 8.95283 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 53 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 78 rows 80 columns, reduced to 67 rows 23 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I After 0.08 seconds - Feasibility pump exiting with objective of 11.327 - took 0.08 seconds
# Cbc0012I Integer solution of 11.32704 found by feasibility pump after 0 iterations and 0 nodes (0.08 seconds)
# Cbc0038I Full problem 78 rows 80 columns, reduced to 19 rows 12 columns
# Cbc0031I 5 added rows had average density of 46.6
# Cbc0013I At root node, 5 cuts changed objective from 7.2393891 to 8.3780699 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 9 row cuts average 34.3 elements, 2 column cuts (2 active)  in 0.015 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 688 row cuts average 58.9 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 6 row cuts average 26.5 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 71 row cuts average 51.1 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 216 row cuts average 18.6 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 11.32704 best solution, best possible 8.3780699 (0.20 seconds)
# Cbc0012I Integer solution of 10.837524 found by DiveCoefficient after 2750 iterations and 32 nodes (0.28 seconds)
# Cbc0038I Full problem 78 rows 80 columns, reduced to 32 rows 16 columns
# Cbc0004I Integer solution of 10.281889 found after 3645 iterations and 48 nodes (0.31 seconds)
# Cbc0001I Search completed - best objective 10.28188861751136, took 3645 iterations and 48 nodes (0.31 seconds)
# Cbc0032I Strong branching done 608 times (5333 iterations), fathomed 3 nodes and fixed 30 variables
# Cbc0035I Maximum depth 11, 259 variables fixed on reduced cost
# Cuts at root node changed objective from 7.23939 to 8.37807
# Probing was tried 100 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.015 seconds)
# Gomory was tried 235 times and created 1016 cuts of which 0 were active after adding rounds of cuts (0.022 seconds)
# Knapsack was tried 100 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 235 times and created 119 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# TwoMirCuts was tried 235 times and created 462 cuts of which 0 were active after adding rounds of cuts (0.025 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 127 times and created 15 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                10.28188862
# Enumerated nodes:               48
# Total iterations:               3645
# Time (CPU seconds):             0.30
# Time (Wallclock seconds):       0.31
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.31   (Wallclock seconds):       0.31
#
# Tour:[0, 7, 8, 6, 1, 4, 3, 2, 5]
# Cost of your tour: 10.281888617512356
# Trial # 4
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/b97eadd35ed1493bac61779f1df22509-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/b97eadd35ed1493bac61779f1df22509-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 92 COLUMNS
# At line 690 RHS
# At line 778 BOUNDS
# At line 868 ENDATA
# Problem MODEL has 87 rows, 89 columns and 347 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 5.98262 - 0.00 seconds
# Cgl0002I 9 variables fixed
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 78 rows, 80 columns (80 integer (72 of which binary)) and 320 elements
# Cbc0038I Initial state - 21 integers unsatisfied sum - 4.25926
# Cbc0038I Pass   1: suminf.    3.50000 (12) obj. 8.11735 iterations 18
# Cbc0038I Pass   2: suminf.    3.50000 (15) obj. 17.0591 iterations 21
# Cbc0038I Pass   3: suminf.    2.50000 (16) obj. 16.8305 iterations 6
# Cbc0038I Pass   4: suminf.    2.55556 (7) obj. 14.6409 iterations 18
# Cbc0038I Pass   5: suminf.    2.11111 (7) obj. 14.0833 iterations 2
# Cbc0038I Pass   6: suminf.    2.77778 (7) obj. 14.4118 iterations 12
# Cbc0038I Pass   7: suminf.    4.00000 (14) obj. 16.2798 iterations 5
# Cbc0038I Pass   8: suminf.    2.00000 (11) obj. 14.7559 iterations 17
# Cbc0038I Pass   9: suminf.    2.66667 (6) obj. 13.2097 iterations 28
# Cbc0038I Pass  10: suminf.    2.00000 (9) obj. 11.6918 iterations 16
# Cbc0038I Pass  11: suminf.    2.66667 (9) obj. 12.405 iterations 22
# Cbc0038I Pass  12: suminf.    4.00000 (16) obj. 11.626 iterations 18
# Cbc0038I Pass  13: suminf.    2.66667 (6) obj. 12.2476 iterations 29
# Cbc0038I Pass  14: suminf.    3.50000 (16) obj. 13.5718 iterations 15
# Cbc0038I Pass  15: suminf.    2.00000 (6) obj. 19.1401 iterations 24
# Cbc0038I Pass  16: suminf.    2.00000 (12) obj. 17.8611 iterations 10
# Cbc0038I Pass  17: suminf.    2.00000 (7) obj. 10.1811 iterations 17
# Cbc0038I Pass  18: suminf.    3.50000 (12) obj. 14.047 iterations 7
# Cbc0038I Pass  19: suminf.    2.00000 (6) obj. 17.8652 iterations 14
# Cbc0038I Pass  20: suminf.    2.88889 (10) obj. 18.5544 iterations 27
# Cbc0038I Pass  21: suminf.    1.33333 (4) obj. 17.2064 iterations 31
# Cbc0038I Pass  22: suminf.    2.40741 (16) obj. 15.9356 iterations 15
# Cbc0038I Pass  23: suminf.    2.55556 (9) obj. 16.7195 iterations 30
# Cbc0038I Pass  24: suminf.    2.55556 (9) obj. 16.2853 iterations 9
# Cbc0038I Pass  25: suminf.    1.77778 (4) obj. 12.1934 iterations 11
# Cbc0038I Pass  26: suminf.    1.55556 (9) obj. 11.9133 iterations 16
# Cbc0038I Pass  27: suminf.    1.77778 (7) obj. 16.2231 iterations 19
# Cbc0038I Pass  28: suminf.    1.55556 (8) obj. 15.4293 iterations 3
# Cbc0038I Pass  29: suminf.    2.00000 (6) obj. 16.8322 iterations 20
# Cbc0038I Pass  30: suminf.    1.55556 (8) obj. 15.9694 iterations 19
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 28 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 78 rows 80 columns, reduced to 74 rows 48 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to 15.4588 (0.03 seconds)
# Cbc0038I Round again with cutoff of 14.5112
# Cbc0038I Pass  30: suminf.    3.50000 (12) obj. 8.11735 iterations 0
# Cbc0038I Pass  31: suminf.    2.56476 (8) obj. 14.5112 iterations 18
# Cbc0038I Pass  32: suminf.    2.57818 (14) obj. 14.5112 iterations 6
# Cbc0038I Pass  33: suminf.    3.11111 (9) obj. 8.48442 iterations 13
# Cbc0038I Pass  34: suminf.    2.00000 (11) obj. 10.4921 iterations 13
# Cbc0038I Pass  35: suminf.    3.40003 (11) obj. 14.5112 iterations 15
# Cbc0038I Pass  36: suminf.    3.40003 (11) obj. 14.5112 iterations 0
# Cbc0038I Pass  37: suminf.    2.66667 (6) obj. 9.51543 iterations 18
# Cbc0038I Pass  38: suminf.    2.00000 (14) obj. 9.06862 iterations 14
# Cbc0038I Pass  39: suminf.    4.76415 (18) obj. 14.5112 iterations 25
# Cbc0038I Pass  40: suminf.    3.00000 (12) obj. 13.9666 iterations 19
# Cbc0038I Pass  41: suminf.    3.67365 (16) obj. 14.5112 iterations 22
# Cbc0038I Pass  42: suminf.    3.75137 (16) obj. 14.5112 iterations 13
# Cbc0038I Pass  43: suminf.    2.04979 (16) obj. 14.5112 iterations 18
# Cbc0038I Pass  44: suminf.    3.50000 (12) obj. 13.4951 iterations 17
# Cbc0038I Pass  45: suminf.    3.50000 (12) obj. 14.047 iterations 5
# Cbc0038I Pass  46: suminf.    3.40003 (11) obj. 14.5112 iterations 17
# Cbc0038I Pass  47: suminf.    3.40003 (11) obj. 14.5112 iterations 0
# Cbc0038I Pass  48: suminf.    2.66667 (6) obj. 9.51543 iterations 12
# Cbc0038I Pass  49: suminf.    2.00000 (14) obj. 9.06862 iterations 18
# Cbc0038I Pass  50: suminf.    4.75671 (19) obj. 14.5112 iterations 28
# Cbc0038I Pass  51: suminf.    3.00000 (12) obj. 13.9666 iterations 19
# Cbc0038I Pass  52: suminf.    3.67365 (16) obj. 14.5112 iterations 25
# Cbc0038I Pass  53: suminf.    3.75137 (16) obj. 14.5112 iterations 13
# Cbc0038I Pass  54: suminf.    2.04979 (16) obj. 14.5112 iterations 18
# Cbc0038I Pass  55: suminf.    3.50000 (12) obj. 13.4951 iterations 17
# Cbc0038I Pass  56: suminf.    3.50000 (12) obj. 14.047 iterations 5
# Cbc0038I Pass  57: suminf.    3.40003 (11) obj. 14.5112 iterations 17
# Cbc0038I Pass  58: suminf.    3.40003 (11) obj. 14.5112 iterations 0
# Cbc0038I Pass  59: suminf.    2.66667 (6) obj. 9.51543 iterations 11
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 78 rows 80 columns, reduced to 73 rows 39 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of 15.4588 - took 0.06 seconds
# Cbc0012I Integer solution of 15.458792 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0038I Full problem 78 rows 80 columns, reduced to 65 rows 21 columns
# Cbc0031I 11 added rows had average density of 40.454545
# Cbc0013I At root node, 11 cuts changed objective from 5.9826201 to 8.1923109 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 68 row cuts average 18.1 elements, 1 column cuts (1 active)  in 0.019 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 581 row cuts average 65.6 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 4 row cuts average 27.5 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 30 row cuts average 58.3 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 283 row cuts average 15.4 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 15.458792 best solution, best possible 8.1923109 (0.20 seconds)
# Cbc0016I Integer solution of 15.240126 found by strong branching after 2649 iterations and 11 nodes (0.24 seconds)
# Cbc0016I Integer solution of 14.873367 found by strong branching after 3343 iterations and 27 nodes (0.27 seconds)
# Cbc0038I Full problem 78 rows 80 columns, reduced to 61 rows 17 columns
# Cbc0016I Integer solution of 13.882938 found by strong branching after 5212 iterations and 53 nodes (0.36 seconds)
# Cbc0012I Integer solution of 11.41171 found by DiveCoefficient after 6459 iterations and 75 nodes (0.42 seconds)
# Cbc0001I Search completed - best objective 11.4117097484967, took 6726 iterations and 80 nodes (0.43 seconds)
# Cbc0032I Strong branching done 1272 times (9943 iterations), fathomed 9 nodes and fixed 28 variables
# Cbc0035I Maximum depth 11, 380 variables fixed on reduced cost
# Cuts at root node changed objective from 5.98262 to 8.19231
# Probing was tried 462 times and created 1108 cuts of which 0 were active after adding rounds of cuts (0.043 seconds)
# Gomory was tried 454 times and created 1563 cuts of which 0 were active after adding rounds of cuts (0.041 seconds)
# Knapsack was tried 100 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 100 times and created 30 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# TwoMirCuts was tried 454 times and created 718 cuts of which 0 were active after adding rounds of cuts (0.040 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 338 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                11.41170975
# Enumerated nodes:               80
# Total iterations:               6726
# Time (CPU seconds):             0.43
# Time (Wallclock seconds):       0.44
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.43   (Wallclock seconds):       0.44
#
# Tour:[0, 8, 4, 1, 7, 2, 3, 6, 5]
# Cost of your tour: 11.411709748496925
# Trial # 5
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/f8739217fc7a45d0aa75dafc6786b99f-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/f8739217fc7a45d0aa75dafc6786b99f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 132 COLUMNS
# At line 1036 RHS
# At line 1164 BOUNDS
# At line 1296 ENDATA
# Problem MODEL has 127 rows, 131 columns and 531 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.92601 - 0.00 seconds
# Cgl0002I 11 variables fixed
# Cgl0003I 0 fixed, 10 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 116 rows, 120 columns (120 integer (110 of which binary)) and 498 elements
# Cbc0038I Initial state - 18 integers unsatisfied sum - 3.81818
# Cbc0038I Pass   1: suminf.    4.40909 (11) obj. 7.60581 iterations 21
# Cbc0038I Pass   2: suminf.    0.90909 (7) obj. 10.3026 iterations 25
# Cbc0038I Pass   3: suminf.    1.09091 (4) obj. 13.5404 iterations 13
# Cbc0038I Pass   4: suminf.    1.90909 (13) obj. 15.6475 iterations 22
# Cbc0038I Pass   5: suminf.    3.57576 (14) obj. 18.9819 iterations 24
# Cbc0038I Pass   6: suminf.    1.90909 (9) obj. 19.8895 iterations 6
# Cbc0038I Pass   7: suminf.    1.90909 (9) obj. 21.2139 iterations 12
# Cbc0038I Pass   8: suminf.    4.40909 (11) obj. 15.4142 iterations 11
# Cbc0038I Pass   9: suminf.    1.57576 (11) obj. 13.7109 iterations 12
# Cbc0038I Pass  10: suminf.    1.09091 (4) obj. 19.9899 iterations 9
# Cbc0038I Pass  11: suminf.    0.90909 (9) obj. 18.3722 iterations 19
# Cbc0038I Pass  12: suminf.    0.90909 (7) obj. 14.332 iterations 8
# Cbc0038I Pass  13: suminf.    1.40909 (10) obj. 14.5339 iterations 4
# Cbc0038I Pass  14: suminf.    3.24242 (13) obj. 24.0526 iterations 25
# Cbc0038I Pass  15: suminf.    4.40909 (16) obj. 23.1092 iterations 13
# Cbc0038I Pass  16: suminf.    2.54545 (8) obj. 24.4205 iterations 28
# Cbc0038I Pass  17: suminf.    1.93939 (13) obj. 23.9409 iterations 29
# Cbc0038I Pass  18: suminf.    2.48485 (14) obj. 29.2804 iterations 23
# Cbc0038I Pass  19: suminf.    5.77273 (19) obj. 30.2399 iterations 28
# Cbc0038I Pass  20: suminf.    1.77273 (10) obj. 31.1117 iterations 23
# Cbc0038I Pass  21: suminf.    3.93939 (17) obj. 31.4784 iterations 8
# Cbc0038I Pass  22: suminf.    2.18182 (6) obj. 30.2284 iterations 14
# Cbc0038I Pass  23: suminf.    1.93939 (14) obj. 30.0827 iterations 9
# Cbc0038I Pass  24: suminf.    1.81818 (4) obj. 24.4889 iterations 30
# Cbc0038I Pass  25: suminf.    1.27273 (7) obj. 24.8603 iterations 15
# Cbc0038I Pass  26: suminf.    1.93939 (14) obj. 23.35 iterations 20
# Cbc0038I Pass  27: suminf.    1.27273 (11) obj. 23.3161 iterations 1
# Cbc0038I Pass  28: suminf.    1.81818 (4) obj. 29.5978 iterations 27
# Cbc0038I Pass  29: suminf.    2.77273 (10) obj. 29.4353 iterations 15
# Cbc0038I Pass  30: suminf.    1.81818 (7) obj. 30.0206 iterations 19
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 64 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 116 rows 120 columns, reduced to 110 rows 53 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting - took 0.05 seconds
# Cbc0031I 7 added rows had average density of 62
# Cbc0013I At root node, 7 cuts changed objective from 6.9260105 to 8.1234084 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 26 row cuts average 93.5 elements, 0 column cuts (0 active)  in 0.030 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 461 row cuts average 100.5 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 69 row cuts average 99.2 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 237 row cuts average 27.8 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is 1
# ...
#
# Objective value:                11.07561153
# Enumerated nodes:               12
# Total iterations:               2409
# Time (CPU seconds):             0.32
# Time (Wallclock seconds):       0.34
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.32   (Wallclock seconds):       0.34
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/c24349ba67494175844ae2377f4a57a4-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/c24349ba67494175844ae2377f4a57a4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 47 COLUMNS
# At line 306 RHS
# At line 349 BOUNDS
# At line 391 ENDATA
# Problem MODEL has 42 rows, 41 columns and 146 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.41271 - 0.00 seconds
# Cgl0002I 6 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 35 rows, 35 columns (35 integer (30 of which binary)) and 126 elements
# Cbc0038I Initial state - 7 integers unsatisfied sum - 2.33333
# Cbc0038I Pass   1: suminf.    2.00000 (7) obj. 7.09912 iterations 2
# Cbc0038I Pass   2: suminf.    2.00000 (6) obj. 11.5514 iterations 11
# Cbc0038I Pass   3: suminf.    1.33333 (4) obj. 11.1311 iterations 5
# Cbc0038I Pass   4: suminf.    2.00000 (4) obj. 12.566 iterations 4
# Cbc0038I Pass   5: suminf.    2.00000 (4) obj. 12.566 iterations 2
# Cbc0038I Pass   6: suminf.    1.33333 (4) obj. 12.7762 iterations 3
# Cbc0038I Pass   7: suminf.    1.33333 (4) obj. 12.7762 iterations 0
# Cbc0038I Pass   8: suminf.    1.33333 (4) obj. 12.5376 iterations 6
# Cbc0038I Pass   9: suminf.    1.33333 (4) obj. 12.7762 iterations 5
# Cbc0038I Pass  10: suminf.    2.00000 (4) obj. 12.566 iterations 3
# Cbc0038I Pass  11: suminf.    1.33333 (4) obj. 12.7762 iterations 3
# Cbc0038I Pass  12: suminf.    2.66667 (8) obj. 12.2774 iterations 3
# Cbc0038I Pass  13: suminf.    3.33333 (9) obj. 11.3864 iterations 9
# Cbc0038I Pass  14: suminf.    2.77778 (9) obj. 11.5398 iterations 8
# Cbc0038I Pass  15: suminf.    2.00000 (4) obj. 12.3333 iterations 4
# Cbc0038I Pass  16: suminf.    1.33333 (4) obj. 12.9648 iterations 7
# Cbc0038I Pass  17: suminf.    1.33333 (4) obj. 12.9648 iterations 2
# Cbc0038I Pass  18: suminf.    2.00000 (4) obj. 12.3333 iterations 6
# Cbc0038I Pass  19: suminf.    1.33333 (4) obj. 12.9648 iterations 9
# Cbc0038I Pass  20: suminf.    2.00000 (6) obj. 10.6031 iterations 8
# Cbc0038I Pass  21: suminf.    3.00000 (12) obj. 9.51249 iterations 5
# Cbc0038I Pass  22: suminf.    2.00000 (4) obj. 13.8732 iterations 8
# Cbc0038I Pass  23: suminf.    3.00000 (9) obj. 13.9329 iterations 3
# Cbc0038I Pass  24: suminf.    3.00000 (9) obj. 13.9329 iterations 1
# Cbc0038I Pass  25: suminf.    1.33333 (4) obj. 15.7183 iterations 9
# Cbc0038I Pass  26: suminf.    2.00000 (4) obj. 15.3661 iterations 4
# Cbc0038I Pass  27: suminf.    2.00000 (4) obj. 15.3661 iterations 0
# Cbc0038I Pass  28: suminf.    1.33333 (4) obj. 15.7183 iterations 6
# Cbc0038I Pass  29: suminf.    3.33333 (9) obj. 19.4717 iterations 9
# Cbc0038I Pass  30: suminf.    2.00000 (6) obj. 18.3456 iterations 4
# Cbc0038I Rounding solution of 14.6433 is better than previous of 1e+50
#
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 35 rows 35 columns, reduced to 24 rows 24 columns
# Cbc0038I Mini branch and bound improved solution from 14.6433 to 8.20128 (0.01 seconds)
# Cbc0038I Round again with cutoff of 8.02241
# Cbc0038I Reduced cost fixing fixed 11 variables on major pass 2
# Cbc0038I Pass  30: suminf.    2.33333 (9) obj. 7.0703 iterations 8
# Cbc0038I Pass  31: suminf.    2.18327 (7) obj. 8.02241 iterations 3
# Cbc0038I Pass  32: suminf.    2.18327 (7) obj. 8.02241 iterations 2
# Cbc0038I Pass  33: suminf.    3.00000 (6) obj. 7.40874 iterations 3
# Cbc0038I Pass  34: suminf.    3.00000 (9) obj. 7.52166 iterations 1
# Cbc0038I Pass  35: suminf.    3.00000 (9) obj. 8.02241 iterations 3
# Cbc0038I Pass  36: suminf.    3.00000 (6) obj. 7.40874 iterations 2
# Cbc0038I Pass  37: suminf.    2.33333 (9) obj. 7.0703 iterations 4
# Cbc0038I Pass  38: suminf.    2.33333 (9) obj. 7.0703 iterations 0
# Cbc0038I Pass  39: suminf.    2.18327 (7) obj. 8.02241 iterations 3
# Cbc0038I Pass  40: suminf.    2.18327 (7) obj. 8.02241 iterations 2
# Cbc0038I Pass  41: suminf.    2.33333 (9) obj. 7.0703 iterations 4
# Cbc0038I Pass  42: suminf.    3.00000 (6) obj. 7.40874 iterations 3
# Cbc0038I Pass  43: suminf.    2.33333 (9) obj. 7.0703 iterations 3
# Cbc0038I Pass  44: suminf.    2.33333 (9) obj. 7.0703 iterations 0
# Cbc0038I Pass  45: suminf.    2.18327 (7) obj. 8.02241 iterations 3
# Cbc0038I Pass  46: suminf.    2.18327 (7) obj. 8.02241 iterations 2
# Cbc0038I Pass  47: suminf.    2.33333 (9) obj. 7.0703 iterations 4
# Cbc0038I Pass  48: suminf.    3.33333 (10) obj. 8.02241 iterations 4
# Cbc0038I Pass  49: suminf.    2.07763 (10) obj. 8.02241 iterations 2
# Cbc0038I Pass  50: suminf.    2.33333 (7) obj. 6.58167 iterations 6
# Cbc0038I Pass  51: suminf.    2.33333 (7) obj. 6.58167 iterations 2
# Cbc0038I Pass  52: suminf.    3.00000 (6) obj. 7.01359 iterations 5
# Cbc0038I Pass  53: suminf.    2.33333 (9) obj. 7.0703 iterations 4
# Cbc0038I Pass  54: suminf.    2.33333 (9) obj. 7.0703 iterations 0
# Cbc0038I Pass  55: suminf.    2.18327 (7) obj. 8.02241 iterations 3
# Cbc0038I Pass  56: suminf.    2.18327 (7) obj. 8.02241 iterations 2
# Cbc0038I Pass  57: suminf.    2.33333 (9) obj. 7.0703 iterations 4
# Cbc0038I Pass  58: suminf.    2.69698 (9) obj. 8.02241 iterations 7
# Cbc0038I Pass  59: suminf.    2.18327 (7) obj. 8.02241 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 14 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 8.20128 - took 0.01 seconds
# Cbc0012I Integer solution of 8.2012802 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 35 rows 35 columns, reduced to 7 rows 5 columns
# Cbc0031I 2 added rows had average density of 5.5
# Cbc0013I At root node, 38 cuts changed objective from 6.4127107 to 8.567335 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 14 row cuts average 2.0 elements, 4 column cuts (4 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 9 row cuts average 5.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 26 row cuts average 4.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 8.20128021337432, took 16 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 13 variables fixed on reduced cost
# Cuts at root node changed objective from 6.41271 to 8.56734
# Probing was tried 2 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 26 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                8.20128021
# Enumerated nodes:               0
# Total iterations:               16
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Tour:[0, 4, 5, 2, 1, 3]
# Cost of your tour: 8.201280213374506
# Trial # 19
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alimohammed1624/.virtualenvs/temp/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/79923e4a8cf243b79d8a4cec95ff372a-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/nz/m7btrx796jl1bvgth7q4y5wm0000gn/T/79923e4a8cf243b79d8a4cec95ff372a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 92 COLUMNS
# At line 690 RHS
# At line 778 BOUNDS
# At line 868 ENDATA
# Problem MODEL has 87 rows, 89 columns and 347 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.54951 - 0.00 seconds
# Cgl0002I 9 variables fixed
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 78 rows, 80 columns (80 integer (72 of which binary)) and 320 elements
# Cbc0038I Initial state - 6 integers unsatisfied sum - 2
# Cbc0038I Pass   1: suminf.    1.33333 (4) obj. 8.11121 iterations 15
# Cbc0038I Pass   2: suminf.    1.55556 (8) obj. 10.2061 iterations 16
# Cbc0038I Pass   3: suminf.    1.55556 (8) obj. 14.2239 iterations 10
# Cbc0038I Pass   4: suminf.    0.00000 (0) obj. 12.3082 iterations 13
# Cbc0038I Solution found of 12.3082
# Cbc0038I Cleaned solution of 12.3082
# Cbc0038I Before mini branch and bound, 56 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 78 rows 80 columns, reduced to 61 rows 17 columns
# Cbc0038I Mini branch and bound improved solution from 12.3082 to 7.67518 (0.01 seconds)
# Cbc0038I Round again with cutoff of 7.6626
# Cbc0038I Reduced cost fixing fixed 54 variables on major pass 2
# Cbc0038I Pass   5: suminf.    2.00000 (6) obj. 7.54951 iterations 6
# Cbc0038I Pass   6: suminf.    2.40029 (13) obj. 7.6626 iterations 14
# Cbc0038I Pass   7: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass   8: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass   9: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  10: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  11: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  12: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  13: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  14: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  15: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  16: suminf.    2.00000 (6) obj. 7.54951 iterations 4
# Cbc0038I Pass  17: suminf.    2.40029 (13) obj. 7.6626 iterations 4
# Cbc0038I Pass  18: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  19: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  20: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  21: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  22: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  23: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  24: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  25: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  26: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  27: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  28: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  29: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  30: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  31: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  32: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  33: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I Pass  34: suminf.    2.40029 (13) obj. 7.6626 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 67 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 78 rows 80 columns, reduced to 14 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of 7.67518 - took 0.06 seconds
# Cbc0012I Integer solution of 7.6751788 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0038I Full problem 78 rows 80 columns, reduced to 14 rows 8 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 7.549512 to 7.549512 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 4 column cuts (4 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 7.67517876010209, took 0 iterations and 0 nodes (0.07 seconds)
# Cbc0035I Maximum depth 0, 53 variables fixed on reduced cost
# Cuts at root node changed objective from 7.54951 to 7.54951
# Probing was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.67517876
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.07
# Time (Wallclock seconds):       0.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.07   (Wallclock seconds):       0.07
#
# Tour:[0, 5, 8, 4, 7, 6, 1, 3, 2]
# Cost of your tour: 7.675178760101859
# Test Passed (10 points)

# %% [markdown]
# ## Answers to Select Problems
#
# ### 1A part A
#
# - Vertex 0: $k$ edges leave and $k$ edges enter.
# - Vertex 1, ..., n-1: 1 edge leaves and 1 edge enters (same as TSP).
#
# ### 1A part B
#
# This is a trick question. There is no need to change any of the time stamp related constraints.

# %% [markdown]
# ## That's All Folks!
